# %% [markdown]
# # Dataset & model setup

# %%
# Import modules
import os
import sys
import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim
import random
import torch.nn.functional as F
import copy
import matplotlib.pyplot as plt
import numpy as np
import time
import io
import json

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Load CIFAR-10 Dataset
d = './data'
if not os.path.exists(d):
    os.mkdir(d)

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2470, 0.2435, 0.2616))
])
test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2470, 0.2435, 0.2616))
])

train_set = datasets.CIFAR10(root=d, train=True, transform=train_transforms, download=True)
test_set = datasets.CIFAR10(root=d, train=False, transform=test_transforms, download=True)

batch_size = 32
global_train_loader = torch.utils.data.DataLoader(
                 dataset=train_set,
                 batch_size=batch_size,
                 shuffle=True)
global_test_loader = torch.utils.data.DataLoader(
                dataset=test_set,
                batch_size=batch_size,
                shuffle=False)
# Out:
# 100%|██████████| 170M/170M [00:04<00:00, 35.4MB/s]

# %%
# Use ResNet-18 model with
# models.resnet18(weights=None, num_classes=10)

# %% [markdown]
# # Client Creation

# %%
from collections import defaultdict
from torch.utils.data import Subset, DataLoader
from collections import Counter
import matplotlib.pyplot as plt


def Dirichlet(labels, alpha, num_clients) :
    n_classes = len(np.unique(labels))
    client_indices = defaultdict(list)

    np.random.seed(42)
    torch.manual_seed(42)

    for c in range(n_classes):
        labels = np.array(train_set.targets)
        idx = np.where(labels == c)[0]
        print("Voici le nombre de labels dans la classe", c, ":", len(idx), "et les indices sont", idx )
        np.random.shuffle(idx)
        proportions = np.random.dirichlet([alpha] * num_clients)
        proportions = (np.cumsum(proportions) * len(idx)).astype(int)[:-1]
        splits = np.split(idx, proportions)


        for client_id, split in enumerate(splits):
            client_indices[client_id].extend(split)

    for cid in range(num_clients):
        if len(client_indices[cid]) == 0:
            random_idx = np.random.randint(0, len(labels))
            client_indices[cid].append(random_idx)
            print(f"Warning: Client {cid} était vide, un échantillon a été ajouté.")


    return client_indices



def count_labels_per_client(train_set, client_indices, num_classes=10):
    counts = np.zeros((len(client_indices), num_classes), dtype=int)

    for cid, indices in client_indices.items():
        labels = np.array(train_set.targets)[indices]
        counter = Counter(labels)
        for cls, cnt in counter.items():
            counts[cid, cls] = cnt

    return counts


def plot_label_distribution(counts):
    plt.figure(figsize=(10, 6))
    plt.imshow(counts, aspect="auto")
    plt.colorbar(label="Number of samples")
    plt.xlabel("Class label")
    plt.ylabel("Client ID")
    plt.title("Label distribution per client (Dirichlet non-IID)")
    plt.tight_layout()
    plt.show()



def build_client_datasets(
    num_clients=10,
    alpha=0.5,
    batch_size=32,
):
    labels = train_set.targets
    client_indices = Dirichlet(labels, alpha, num_clients)

    counts = count_labels_per_client(train_set, client_indices, num_classes=10)
    print(counts)
    counts_norm = counts / counts.sum(axis=1, keepdims=True)
    plot_label_distribution(counts_norm)

    i = 0
    clients = []

    for cid, indices in client_indices.items():

        model = models.resnet18(weights=None, num_classes=10).to(device)

        number_sample = 0
        for j in range (len(counts[i])) :
          number_sample += counts[i][j]


        loader = torch.utils.data.DataLoader(
                  dataset= Subset(train_set, indices) ,
                  batch_size=batch_size,
                  shuffle=True,
                  drop_last=True) #supprime le batch s'il fait moinsde 32 images j'en avais besoin pour éviter des erreurs de batch de size 1

        client = {"client_id": i,
            "local_dataset": loader,
            "local_model" : model,
            "optimizer": optim.SGD(model.parameters(), lr=0.01, momentum=0.9),
            "number_sample" : number_sample}

        clients.append(client)
        i += 1


    return clients


clients = build_client_datasets(    num_clients=10,
    alpha=0.1,
    batch_size=32)


number_sample_clients = [x["number_sample"] for x in clients]
print(number_sample_clients)
# Out:
# Voici le nombre de labels dans la classe 0 : 5000 et les indices sont [   29    30    35 ... 49941 49992 49994]
# Voici le nombre de labels dans la classe 1 : 5000 et les indices sont [    4     5    32 ... 49993 49998 49999]
# Voici le nombre de labels dans la classe 2 : 5000 et les indices sont [    6    13    18 ... 49987 49991 49995]
# Voici le nombre de labels dans la classe 3 : 5000 et les indices sont [    9    17    21 ... 49979 49982 49983]
# Voici le nombre de labels dans la classe 4 : 5000 et les indices sont [    3    10    20 ... 49981 49984 49990]
# Voici le nombre de labels dans la classe 5 : 5000 et les indices sont [   27    40    51 ... 49964 49980 49988]
# Voici le nombre de labels dans la classe 6 : 5000 et les indices sont [    0    19    22 ... 49962 49966 49996]
# Voici le nombre de labels dans la classe 7 : 5000 et les indices sont [    7    11    12 ... 49965 49978 49986]
# Voici le nombre de labels dans la classe 8 : 5000 et les indices sont [    8    62    69 ... 49968 49976 49985]
# Voici le nombre de labels dans la classe 9 : 5000 et les indices sont [    1     2    14 ... 49963 49971 49997]
# [[   0    0 1015 3485    4   47    0 2966    0 1831]
#  [  24    0  240  994 4559    0 2299    1  182    0]
#  [   0  412 2539  492  390    0  223    0    0    0]
#  [1495   52   58    0    0    0   60    0    0   85]
#  [3479    0  209    0    0  753    0    0    0   30]
#  [   0    9  100    7   29    3    0    0 4336    0]
#  [   1    0    0    0    0 3102    1 2017    0    0]
#  [   0 1489    0   21    0    1   66   15    0    1]
#  [   0 3034  838    0    0  498 2350    0  458 2650]
#  [   1    4    1    1   18  596    1    1   24  403]]
# [np.int64(9348), np.int64(8299), np.int64(4056), np.int64(1750), np.int64(4471), np.int64(4484), np.int64(5121), np.int64(1593), np.int64(9828), np.int64(1050)]

# %%
def quantize_row(sub_tensor, bits=8):

    qmin = -(2 ** (bits - 1))
    qmax = (2 ** (bits - 1)) - 1

    max_val = sub_tensor.abs().max()


    scale = max_val / qmax if max_val != 0 else 1.0

    q_tensor = (sub_tensor / scale).round().clamp(qmin, qmax).to(torch.int8)

    return q_tensor, scale

def quantize_model_state_dict(state_dict, bits=8):
    q_state = {}
    scales = {}
    qmin = -(2 ** (bits - 1))
    qmax = (2 ** (bits - 1)) - 1

    for name, tensor in state_dict.items():
        if "bn" not in name and "bias" not in name and tensor.dim() >= 2 and tensor.dtype == torch.float32:

            flat_tensor = tensor.view(tensor.shape[0], -1)

            max_val = flat_tensor.abs().max(dim=1).values

            # On ajoute un petit epsilon pour éviter la division par zéro
            scale = max_val / qmax
            scale[scale == 0] = 1.0

            view_shape = [tensor.shape[0]] + [1] * (tensor.dim() - 1)
            q_tensor = (tensor / scale.view(view_shape)).round().clamp(qmin, qmax).to(torch.int8)

            q_state[name] = q_tensor
            scales[name] = scale
        else:
            # Pas de quantification pour les biais ou BN
            q_state[name] = tensor
            scales[name] = None

    return q_state, scales

def dequantize_tensor(q_tensor, scale):
    return q_tensor.float() * scale


def dequantize_model_state_dict(q_state, scales):
    fp32_state = {}

    for name, q_tensor in q_state.items():
        scale = scales.get(name)

        if scale is not None:
            view_shape = [q_tensor.shape[0]] + [1] * (q_tensor.dim() - 1)
            fp32_state[name] = q_tensor.float() * scale.view(view_shape)
        else:
            fp32_state[name] = q_tensor.clone()

    return fp32_state

# %% [markdown]
# # Federated Learning Training

# %%
def client_load_model(client, model):
    client["local_model"].load_state_dict(model.state_dict())

def client_local_training(client):
    criterion = nn.CrossEntropyLoss()
    optimizer = client["optimizer"]
    dataset = client["local_dataset"]
    model = client["local_model"].to(device)
    model.train()

    for batch_idx, (x, target) in enumerate(dataset):
        x, target = x.to(device), target.to(device)
        out = model(x)
        loss = criterion(out, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    return client["local_model"].state_dict()

def client_send_update(client):
    fp32 = client["local_model"].state_dict()
    q_state, scales = quantize_model_state_dict(fp32)
    return q_state, scales


def server_aggregate_quantized(q_updates, client_id):
  fp32_models = []
  number_sample = [number_sample_clients[i] for i in client_id]
  total_sample = sum(number_sample)

  if len(q_updates) == 0:
    return None

  for q_state, scales in q_updates:
      fp32_model = dequantize_model_state_dict(q_state, scales)
      fp32_models.append(fp32_model)

  averaged_model = copy.deepcopy(fp32_models[0])
  with torch.no_grad():
    for k in averaged_model.keys():
        i = 0
        somme = 0
        for m in fp32_models :
          somme += m[k] * number_sample[i]
          i += 1
        averaged_model[k]  = somme / total_sample
  return averaged_model
def evaluate(model, dataset):
    model.to(device)
    model.eval()
    criterion = nn.CrossEntropyLoss()
    total_loss, total, correct = 0, 0, 0

    with torch.no_grad():
        for x, target in dataset:
            x, target = x.to(device), target.to(device)
            out = model(x)
            loss = criterion(out, target)
            _, pred_label = torch.max(out, 1)
            total_loss += loss.item()
            total += x.size(0)
            correct += (pred_label == target).sum().item()

    avg_loss = total_loss / len(dataset)
    acc = correct / total
    print(f"loss: {avg_loss:.4f}, acc: {acc:.4f}")
    return avg_loss, acc

def get_model_size(model):
    buffer = io.BytesIO()
    torch.save(model.state_dict(), buffer)
    size_MB = buffer.getbuffer().nbytes / 1e6
    return size_MB

def get_quantized_model_size(q_state):
    buffer = io.BytesIO()
    torch.save(q_state, buffer)
    size_MB = buffer.getbuffer().nbytes / 1e6
    return size_MB

def federated_learning_loop_int8(save_dir):
    # Set seed
    torch.manual_seed(42)
    global_model = models.resnet18(weights=None, num_classes=10).to(device)

    client_participation_fraction = 0.2
    rounds = 300
    eval_interval = 10  # Measure costly metrics every X rounds
    save_interval = 50  # Save model every Y rounds
    os.makedirs(save_dir, exist_ok=True)

    metrics = {
        "round": [],
        "loss": [],
        "accuracy": [],
        "round_time": [],
        "model_size": []
    }
    best_acc = 0.0

    for r in range(rounds):
        print(f"\nRound {r+1}")

        # Start the timer
        start_time = time.time()

        # Broadcast global model to clients
        for c in clients:
            client_load_model(c, global_model)

        q_updates = []
        client_id = []

        # Selected clients perform local training
        for c in clients:
            if random.random() <= client_participation_fraction:
              client_local_training(c)
              q_updates.append(client_send_update(c))
              client_id.append(c["client_id"])


        # Aggregate models from participating clients
        if len(q_updates) == 0:
          print("No client participated this round — keeping global model.")
          continue

        else:
          aggregated_model = server_aggregate_quantized(q_updates, client_id)

        # Update global model
        global_model.load_state_dict(aggregated_model)

        # Stop the timer before computing the metrics
        round_time = time.time() - start_time

        # Evaluation
        print("Time evaluation")
        t0 = time.time()
        loss, acc = evaluate(global_model, global_test_loader)
        t1 = time.time()
        print(f"Durée de evaluate : {t1 - t0:.3f} s")

        if (r + 1) % eval_interval == 0 or r == 0 or r == rounds - 1:
            model_size = get_model_size(global_model)
        else:
            model_size = metrics["model_size"][-1]

        # Save metrics for plotting
        metrics["round"].append(r+1)
        metrics["round_time"].append(round_time)
        metrics["loss"].append(loss)
        metrics["accuracy"].append(acc)
        metrics["model_size"].append(model_size)

        total_bytes = 0
        for q_state, scales in q_updates:
            buffer = io.BytesIO()
            torch.save(q_state, buffer)
            total_bytes += buffer.getbuffer().nbytes
        print(f"Total sent this round (INT8): {total_bytes/1e6:.3f} MB")

        # Save model periodically
        if (r + 1) % save_interval == 0:
          example_q_state, example_scales = client_send_update(clients[0])
          quantized_size = get_quantized_model_size(example_q_state)
          print(f"INT8 model update size: {quantized_size:.3f} MB")

        # Save best model so far
        if acc > best_acc:
            best_acc = acc
            torch.save(global_model.state_dict(), f"{save_dir}/best_model.pth")
            print(f"New best model saved (acc={acc:.4f})")

    # Save final model
    #torch.save(global_model.state_dict(), f"{save_dir}/final_model.pth")
    print("Final model saved")

    return metrics

# %%
def plot_metrics(metrics, filename):
    rounds = np.array(metrics["round"])
    loss = np.array(metrics["loss"])
    acc = np.array(metrics["accuracy"])
    round_time = np.array(metrics["round_time"])
    model_size = np.array(metrics["model_size"])

    plt.style.use('seaborn-v0_8-paper')

    fig, axes = plt.subplots(2, 2, figsize=(12, 8))
    axes = axes.ravel()

    # Loss
    axes[0].plot(rounds, loss, color='tab:blue', linewidth=2)
    axes[0].set_title("Global Model Loss", fontsize=15)
    axes[0].set_xlabel("Round", fontsize=13)
    axes[0].set_ylabel("Loss", fontsize=13)
    axes[0].grid(True)

    # Accuracy
    axes[1].plot(rounds, acc, color='tab:orange', linewidth=2)
    axes[1].set_title("Global Model Accuracy", fontsize=15)
    axes[1].set_xlabel("Round", fontsize=13)
    axes[1].set_ylabel("Accuracy", fontsize=13)
    axes[1].grid(True)

    # Round time
    axes[2].plot(rounds, round_time, color='tab:green', linewidth=2)
    axes[2].set_title("Round Duration", fontsize=15)
    axes[2].set_xlabel("Round", fontsize=13)
    axes[2].set_ylabel("Time (s)", fontsize=13)
    axes[2].grid(True)

    # Model size
    axes[3].plot(rounds, model_size, color='tab:red', linewidth=2)
    axes[3].set_title("Model Size", fontsize=15)
    axes[3].set_xlabel("Round", fontsize=13)
    axes[3].set_ylabel("Size (MB)", fontsize=13)
    axes[3].grid(True)

    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()

    print(f"Plot saved to {filename}")

# %%
def summarize_metrics(metrics, filename):
    rounds = np.array(metrics["round"])
    losses = np.array(metrics["loss"])
    accs = np.array(metrics["accuracy"])
    round_times = np.array(metrics["round_time"])
    model_sizes = np.array(metrics["model_size"])

    mean_round_time = np.nanmean(round_times)
    std_round_time = np.nanstd(round_times)
    total_training_time = np.nansum(round_times)

    final_loss = losses[-1]
    final_acc = accs[-1]
    best_loss = np.nanmin(losses)
    best_loss_round = rounds[np.nanargmin(losses)]
    best_acc = np.nanmax(accs)
    best_acc_round = rounds[np.nanargmax(accs)]

    initial_model_size = model_sizes[0]
    final_model_size = model_sizes[-1]
    best_acc_model_size = model_sizes[np.nanargmax(accs)]
    best_loss_model_size = model_sizes[np.nanargmin(losses)]

    size_reduction = initial_model_size - final_model_size
    size_reduction_pct = (size_reduction / initial_model_size) * 100 if initial_model_size > 0 else 0
    size_reduction_best_acc = initial_model_size - best_acc_model_size
    size_reduction_pct_best_acc = (size_reduction_best_acc / initial_model_size) * 100 if initial_model_size > 0 else 0
    size_reduction_best_loss = initial_model_size - best_loss_model_size
    size_reduction_pct_best_loss = (size_reduction_best_loss / initial_model_size) * 100 if initial_model_size > 0 else 0

    acc_per_mb = best_acc / best_acc_model_size if best_acc_model_size > 0 else np.nan

    summary = {
        "final_loss": float(final_loss),
        "best_loss": float(best_loss),
        "final_accuracy": float(final_acc),
        "best_accuracy": float(best_acc),
        "best_loss_round": int(best_loss_round),
        "best_acc_round": int(best_acc_round),
        "mean_round_time": float(mean_round_time),
        "std_round_time": float(std_round_time),
        "total_training_time": float(total_training_time),
        "initial_model_size_MB": float(initial_model_size),
        "final_model_size_MB": float(final_model_size),
        "best_acc_model_size_MB": float(best_acc_model_size),
        "best_loss_model_size_MB": float(best_loss_model_size),
        "size_reduction_MB": float(size_reduction),
        "size_reduction_pct": float(size_reduction_pct),
        "size_reduction_best_acc_MB": float(size_reduction_best_acc),
        "size_reduction_pct_best_acc": float(size_reduction_pct_best_acc),
        "size_reduction_best_loss_MB": float(size_reduction_best_loss),
        "size_reduction_pct_best_loss": float(size_reduction_pct_best_loss),
        "accuracy_per_MB": float(acc_per_mb)
    }

    print("=== Training Summary ===")
    print(f"Final loss: {summary['final_loss']:.4f}")
    print(f"Best loss: {summary['best_loss']:.4f}")
    print(f"Final accuracy: {summary['final_accuracy']:.4f}")
    print(f"Best accuracy: {summary['best_accuracy']:.4f}")
    print(f"Best loss round: {summary['best_loss_round']}")
    print(f"Best accuracy round: {summary['best_acc_round']}")
    print()
    print(f"Mean round time: {summary['mean_round_time']:.3f} s")
    print(f"Std round time: {summary['std_round_time']:.3f} s")
    print(f"Total training time: {summary['total_training_time']:.3f} s")
    print()
    print(f"Initial model size: {summary['initial_model_size_MB']:.3f} MB")
    print(f"Final model size: {summary['final_model_size_MB']:.3f} MB")
    print(f"Model size at best accuracy: {summary['best_acc_model_size_MB']:.3f} MB")
    print(f"Model size at best loss: {summary['best_loss_model_size_MB']:.3f} MB")
    print()
    print(f"Size reduction (final): {summary['size_reduction_MB']:.3f} MB ({summary['size_reduction_pct']:.2f}%)")
    print(f"Size reduction (best accuracy): {summary['size_reduction_best_acc_MB']:.3f} MB ({summary['size_reduction_pct_best_acc']:.2f}%)")
    print(f"Size reduction (best loss): {summary['size_reduction_best_loss_MB']:.3f} MB ({summary['size_reduction_pct_best_loss']:.2f}%)")
    print()
    print(f"Accuracy per MB: {summary['accuracy_per_MB']:.4f}")

    with open(filename, "w") as f:
        json.dump(summary, f, indent=4)

    print(f"\nSummary saved to {filename}")
    return summary

# %%
# Run loop
run_save_dir = "checkpoints"
metrics = federated_learning_loop_int8(run_save_dir)
# Out:
# Round 1
# Time evaluation
# loss: 2.9696, acc: 0.1000
# Durée de evaluate : 3.538 s
# Total sent this round (INT8): 33.860 MB
# New best model saved (acc=0.1000)
#
# Round 2
# Time evaluation
# loss: 3.2021, acc: 0.1000
# Durée de evaluate : 3.877 s
# Total sent this round (INT8): 45.147 MB
#
# Round 3
# Time evaluation
# loss: 3.9937, acc: 0.1229
# Durée de evaluate : 3.477 s
# Total sent this round (INT8): 33.860 MB
# New best model saved (acc=0.1229)
#
# Round 4
# Time evaluation
# loss: 6.7564, acc: 0.2012
# Durée de evaluate : 3.443 s
# Total sent this round (INT8): 11.287 MB
# New best model saved (acc=0.2012)
#
# Round 5
# Time evaluation
# loss: 3.8134, acc: 0.1148
# Durée de evaluate : 4.099 s
# Total sent this round (INT8): 22.573 MB
#
# Round 6
# Time evaluation
# loss: 3.5418, acc: 0.1000
# Durée de evaluate : 3.481 s
# Total sent this round (INT8): 33.860 MB
#
# Round 7
# No client participated this round — keeping global model.
#
# Round 8
# Time evaluation
# loss: 3.8248, acc: 0.1059
# Durée de evaluate : 3.786 s
# Total sent this round (INT8): 45.147 MB
#
# Round 9
# Time evaluation
# loss: 4.2768, acc: 0.1840
# Durée de evaluate : 3.914 s
# Total sent this round (INT8): 22.573 MB
#
# Round 10
# Time evaluation
# loss: 4.2524, acc: 0.2081
# Durée de evaluate : 3.417 s
# Total sent this round (INT8): 22.573 MB
# New best model saved (acc=0.2081)
#
# Round 11
# Time evaluation
# loss: 3.7231, acc: 0.2116
# Durée de evaluate : 3.469 s
# Total sent this round (INT8): 45.147 MB
# New best model saved (acc=0.2116)
#
# Round 12
# Time evaluation
# loss: 4.2630, acc: 0.1482
# Durée de evaluate : 3.482 s
# Total sent this round (INT8): 22.573 MB
#
# Round 13
# Time evaluation
# loss: 3.2306, acc: 0.2497
# Durée de evaluate : 3.472 s
# Total sent this round (INT8): 22.573 MB
# New best model saved (acc=0.2497)
#
# Round 14
# Time evaluation
# loss: 9.8900, acc: 0.1590
# Durée de evaluate : 4.012 s
# Total sent this round (INT8): 11.287 MB
#
# Round 15
# Time evaluation
# loss: 2.9625, acc: 0.1646
# Durée de evaluate : 3.943 s
# Total sent this round (INT8): 45.147 MB
#
# Round 16
# Time evaluation
# loss: 5.1955, acc: 0.1168
# Durée de evaluate : 3.475 s
# Total sent this round (INT8): 11.287 MB
#
# Round 17
# Time evaluation
# loss: 2.6666, acc: 0.1658
# Durée de evaluate : 3.518 s
# Total sent this round (INT8): 45.147 MB
#
# Round 18
# Time evaluation
# loss: 3.2147, acc: 0.3640
# Durée de evaluate : 3.402 s
# Total sent this round (INT8): 11.287 MB
# New best model saved (acc=0.3640)
#
# Round 19
# Time evaluation
# loss: 2.9344, acc: 0.1761
# Durée de evaluate : 3.659 s
# Total sent this round (INT8): 22.573 MB
#
# Round 20
# Time evaluation
# loss: 4.8489, acc: 0.1706
# Durée de evaluate : 3.404 s
# Total sent this round (INT8): 11.287 MB
#
# Round 21
# Time evaluation
# loss: 6.2543, acc: 0.2268
# Durée de evaluate : 3.444 s
# Total sent this round (INT8): 22.573 MB
#
# Round 22
# No client participated this round — keeping global model.
#
# Round 23
# Time evaluation
# loss: 7.2764, acc: 0.1901
# Durée de evaluate : 3.611 s
# Total sent this round (INT8): 11.287 MB
#
# Round 24
# Time evaluation
# loss: 4.1680, acc: 0.1747
# Durée de evaluate : 3.507 s
# Total sent this round (INT8): 11.287 MB
#
# Round 25
# Time evaluation
# loss: 2.9554, acc: 0.1844
# Durée de evaluate : 3.439 s
# Total sent this round (INT8): 45.147 MB
#
# Round 26
# Time evaluation
# loss: 8.6783, acc: 0.1468
# Durée de evaluate : 3.798 s
# Total sent this round (INT8): 11.287 MB
#
# Round 27
# Time evaluation
# loss: 6.7334, acc: 0.1000
# Durée de evaluate : 3.417 s
# Total sent this round (INT8): 11.287 MB
#
# Round 28
# Time evaluation
# loss: 8.0019, acc: 0.1555
# Durée de evaluate : 3.657 s
# Total sent this round (INT8): 11.287 MB
#
# Round 29
# Time evaluation
# loss: 5.6134, acc: 0.1003
# Durée de evaluate : 3.440 s
# Total sent this round (INT8): 11.287 MB
#
# Round 30
# Time evaluation
# loss: 3.4906, acc: 0.1000
# Durée de evaluate : 3.640 s
# Total sent this round (INT8): 22.573 MB
#
# Round 31
# Time evaluation
# loss: 4.9562, acc: 0.1525
# Durée de evaluate : 3.469 s
# Total sent this round (INT8): 11.287 MB
#
# Round 32
# Time evaluation
# loss: 6.3934, acc: 0.1611
# Durée de evaluate : 3.969 s
# Total sent this round (INT8): 11.287 MB
#
# Round 33
# Time evaluation
# loss: 4.1284, acc: 0.2514
# Durée de evaluate : 3.596 s
# Total sent this round (INT8): 22.573 MB
#
# Round 34
# Time evaluation
# loss: 2.5358, acc: 0.2635
# Durée de evaluate : 3.998 s
# Total sent this round (INT8): 22.573 MB
#
# Round 35
# No client participated this round — keeping global model.
#
# Round 36
# Time evaluation
# loss: 2.2857, acc: 0.2626
# Durée de evaluate : 3.832 s
# Total sent this round (INT8): 33.860 MB
#
# Round 37
# Time evaluation
# loss: 2.3570, acc: 0.2738
# Durée de evaluate : 3.451 s
# Total sent this round (INT8): 45.147 MB
#
# Round 38
# Time evaluation
# loss: 5.6829, acc: 0.1657
# Durée de evaluate : 4.021 s
# Total sent this round (INT8): 11.287 MB
#
# Round 39
# Time evaluation
# loss: 3.6415, acc: 0.1434
# Durée de evaluate : 3.466 s
# Total sent this round (INT8): 33.860 MB
#
# Round 40
# Time evaluation
# loss: 4.2045, acc: 0.2019
# Durée de evaluate : 3.492 s
# Total sent this round (INT8): 11.287 MB
#
# Round 41
# Time evaluation
# loss: 3.5684, acc: 0.1957
# Durée de evaluate : 3.448 s
# Total sent this round (INT8): 22.573 MB
#
# Round 42
# Time evaluation
# loss: 2.5713, acc: 0.2978
# Durée de evaluate : 3.475 s
# Total sent this round (INT8): 33.860 MB
#
# Round 43
# Time evaluation
# loss: 2.4712, acc: 0.1915
# Durée de evaluate : 3.517 s
# Total sent this round (INT8): 45.147 MB
#
# Round 44
# Time evaluation
# loss: 2.4671, acc: 0.3690
# Durée de evaluate : 3.501 s
# Total sent this round (INT8): 33.860 MB
# New best model saved (acc=0.3690)
#
# Round 45
# Time evaluation
# loss: 2.6996, acc: 0.3426
# Durée de evaluate : 3.553 s
# Total sent this round (INT8): 22.573 MB
#
# Round 46
# Time evaluation
# loss: 2.5390, acc: 0.3926
# Durée de evaluate : 4.027 s
# Total sent this round (INT8): 33.860 MB
# New best model saved (acc=0.3926)
#
# Round 47
# Time evaluation
# loss: 2.5814, acc: 0.2334
# Durée de evaluate : 3.727 s
# Total sent this round (INT8): 22.573 MB
#
# Round 48
# Time evaluation
# loss: 2.6506, acc: 0.3930
# Durée de evaluate : 3.480 s
# Total sent this round (INT8): 22.573 MB
# New best model saved (acc=0.3930)
#
# Round 49
# Time evaluation
# loss: 2.2783, acc: 0.2902
# Durée de evaluate : 3.497 s
# Total sent this round (INT8): 45.147 MB
#
# Round 50
# Time evaluation
# loss: 2.9623, acc: 0.2117
# Durée de evaluate : 3.409 s
# Total sent this round (INT8): 22.573 MB
# INT8 model update size: 11.287 MB
#
# Round 51
# Time evaluation
# loss: 3.2886, acc: 0.2527
# Durée de evaluate : 3.520 s
# Total sent this round (INT8): 45.147 MB
#
# Round 52
# Time evaluation
# loss: 2.4585, acc: 0.3165
# Durée de evaluate : 3.425 s
# Total sent this round (INT8): 22.573 MB
#
# Round 53
# Time evaluation
# loss: 2.2191, acc: 0.2958
# Durée de evaluate : 3.459 s
# Total sent this round (INT8): 33.860 MB
#
# Round 54
# Time evaluation
# loss: 8.4130, acc: 0.1705
# Durée de evaluate : 3.721 s
# Total sent this round (INT8): 11.287 MB
#
# Round 55
# Time evaluation
# loss: 3.1291, acc: 0.1000
# Durée de evaluate : 3.531 s
# Total sent this round (INT8): 11.287 MB
#
# Round 56
# No client participated this round — keeping global model.
#
# Round 57
# Time evaluation
# loss: 2.4173, acc: 0.2859
# Durée de evaluate : 3.434 s
# Total sent this round (INT8): 45.147 MB
#
# Round 58
# Time evaluation
# loss: 3.3913, acc: 0.4009
# Durée de evaluate : 3.438 s
# Total sent this round (INT8): 11.287 MB
# New best model saved (acc=0.4009)
#
# Round 59
# Time evaluation
# loss: 5.7017, acc: 0.2929
# Durée de evaluate : 3.455 s
# Total sent this round (INT8): 11.287 MB
#
# Round 60
# Time evaluation
# loss: 2.9142, acc: 0.2408
# Durée de evaluate : 3.958 s
# Total sent this round (INT8): 22.573 MB
#
# Round 61
# Time evaluation
# loss: 2.9857, acc: 0.2075
# Durée de evaluate : 3.463 s
# Total sent this round (INT8): 33.860 MB
#
# Round 62
# Time evaluation
# loss: 2.0441, acc: 0.4032
# Durée de evaluate : 3.957 s
# Total sent this round (INT8): 22.573 MB
# New best model saved (acc=0.4032)
#
# Round 63
# Time evaluation
# loss: 2.6082, acc: 0.4212
# Durée de evaluate : 3.778 s
# Total sent this round (INT8): 22.573 MB
# New best model saved (acc=0.4212)
#
# Round 64
# Time evaluation
# loss: 3.9434, acc: 0.1937
# Durée de evaluate : 3.460 s
# Total sent this round (INT8): 11.287 MB
#
# Round 65
# Time evaluation
# loss: 3.9577, acc: 0.1964
# Durée de evaluate : 3.434 s
# Total sent this round (INT8): 11.287 MB
#
# Round 66
# Time evaluation
# loss: 4.0732, acc: 0.1657
# Durée de evaluate : 4.047 s
# Total sent this round (INT8): 11.287 MB
#
# Round 67
# Time evaluation
# loss: 4.5972, acc: 0.2829
# Durée de evaluate : 3.566 s
# Total sent this round (INT8): 11.287 MB
#
# Round 68
# Time evaluation
# loss: 2.4251, acc: 0.2869
# Durée de evaluate : 3.850 s
# Total sent this round (INT8): 33.860 MB
#
# Round 69
# Time evaluation
# loss: 4.0947, acc: 0.2082
# Durée de evaluate : 3.500 s
# Total sent this round (INT8): 11.287 MB
#
# Round 70
# Time evaluation
# loss: 4.8712, acc: 0.1857
# Durée de evaluate : 3.832 s
# Total sent this round (INT8): 11.287 MB
#
# Round 71
# Time evaluation
# loss: 4.1854, acc: 0.1879
# Durée de evaluate : 3.531 s
# Total sent this round (INT8): 11.287 MB
#
# Round 72
# Time evaluation
# loss: 1.9571, acc: 0.3393
# Durée de evaluate : 4.043 s
# Total sent this round (INT8): 56.433 MB
#
# Round 73
# Time evaluation
# loss: 2.3988, acc: 0.2241
# Durée de evaluate : 3.552 s
# Total sent this round (INT8): 22.573 MB
#
# Round 74
# Time evaluation
# loss: 3.4650, acc: 0.2181
# Durée de evaluate : 3.779 s
# Total sent this round (INT8): 11.287 MB
#
# Round 75
# Time evaluation
# loss: 1.9297, acc: 0.4271
# Durée de evaluate : 3.651 s
# Total sent this round (INT8): 56.433 MB
# New best model saved (acc=0.4271)
#
# Round 76
# Time evaluation
# loss: 4.1127, acc: 0.2772
# Durée de evaluate : 3.482 s
# Total sent this round (INT8): 11.287 MB
#
# Round 77
# Time evaluation
# loss: 2.5380, acc: 0.2396
# Durée de evaluate : 3.999 s
# Total sent this round (INT8): 22.573 MB
#
# Round 78
# Time evaluation
# loss: 2.8001, acc: 0.2284
# Durée de evaluate : 3.471 s
# Total sent this round (INT8): 33.860 MB
#
# Round 79
# Time evaluation
# loss: 3.6118, acc: 0.1693
# Durée de evaluate : 3.437 s
# Total sent this round (INT8): 22.573 MB
#
# Round 80
# Time evaluation
# loss: 3.0303, acc: 0.2955
# Durée de evaluate : 3.808 s
# Total sent this round (INT8): 11.287 MB
#
# Round 81
# Time evaluation
# loss: 3.6908, acc: 0.3074
# Durée de evaluate : 4.006 s
# Total sent this round (INT8): 11.287 MB
#
# Round 82
# Time evaluation
# loss: 3.1576, acc: 0.2149
# Durée de evaluate : 3.538 s
# Total sent this round (INT8): 22.573 MB
#
# Round 83
# Time evaluation
# loss: 1.9817, acc: 0.2728
# Durée de evaluate : 3.526 s
# Total sent this round (INT8): 22.573 MB
#
# Round 84
# No client participated this round — keeping global model.
#
# Round 85
# Time evaluation
# loss: 2.3152, acc: 0.4538
# Durée de evaluate : 3.674 s
# Total sent this round (INT8): 22.573 MB
# New best model saved (acc=0.4538)
#
# Round 86
# Time evaluation
# loss: 3.1794, acc: 0.2938
# Durée de evaluate : 3.457 s
# Total sent this round (INT8): 11.287 MB
#
# Round 87
# Time evaluation
# loss: 1.6450, acc: 0.4667
# Durée de evaluate : 3.730 s
# Total sent this round (INT8): 45.147 MB
# New best model saved (acc=0.4667)
#
# Round 88
# No client participated this round — keeping global model.
#
# Round 89
# Time evaluation
# loss: 3.2930, acc: 0.4452
# Durée de evaluate : 4.002 s
# Total sent this round (INT8): 11.287 MB
#
# Round 90
# Time evaluation
# loss: 2.0343, acc: 0.3209
# Durée de evaluate : 4.043 s
# Total sent this round (INT8): 22.573 MB
#
# Round 91
# Time evaluation
# loss: 6.2365, acc: 0.1780
# Durée de evaluate : 3.530 s
# Total sent this round (INT8): 11.287 MB
#
# Round 92
# No client participated this round — keeping global model.
#
# Round 93
# Time evaluation
# loss: 3.0816, acc: 0.2901
# Durée de evaluate : 3.403 s
# Total sent this round (INT8): 22.573 MB
#
# Round 94
# No client participated this round — keeping global model.
#
# Round 95
# Time evaluation
# loss: 3.3009, acc: 0.3148
# Durée de evaluate : 4.021 s
# Total sent this round (INT8): 11.287 MB
#
# Round 96
# Time evaluation
# loss: 2.8655, acc: 0.3180
# Durée de evaluate : 3.996 s
# Total sent this round (INT8): 22.573 MB
#
# Round 97
# Time evaluation
# loss: 2.7061, acc: 0.2876
# Durée de evaluate : 3.497 s
# Total sent this round (INT8): 11.287 MB
#
# Round 98
# Time evaluation
# loss: 3.5896, acc: 0.1851
# Durée de evaluate : 3.483 s
# Total sent this round (INT8): 11.287 MB
#
# Round 99
# Time evaluation
# loss: 3.3104, acc: 0.3019
# Durée de evaluate : 3.428 s
# Total sent this round (INT8): 11.287 MB
#
# Round 100
# Time evaluation
# loss: 4.2354, acc: 0.1601
# Durée de evaluate : 3.979 s
# Total sent this round (INT8): 11.287 MB
# INT8 model update size: 11.287 MB
#
# Round 101
# No client participated this round — keeping global model.
#
# Round 102
# Time evaluation
# loss: 2.6835, acc: 0.1824
# Durée de evaluate : 3.447 s
# Total sent this round (INT8): 22.573 MB
#
# Round 103
# Time evaluation
# loss: 1.8777, acc: 0.4396
# Durée de evaluate : 4.025 s
# Total sent this round (INT8): 22.573 MB
#
# Round 104
# Time evaluation
# loss: 3.0954, acc: 0.3346
# Durée de evaluate : 3.483 s
# Total sent this round (INT8): 11.287 MB
#
# Round 105
# Time evaluation
# loss: 3.2005, acc: 0.4374
# Durée de evaluate : 3.540 s
# Total sent this round (INT8): 11.287 MB
#
# Round 106
# No client participated this round — keeping global model.
#
# Round 107
# Time evaluation
# loss: 2.6926, acc: 0.2520
# Durée de evaluate : 3.474 s
# Total sent this round (INT8): 22.573 MB
#
# Round 108
# Time evaluation
# loss: 3.2401, acc: 0.1972
# Durée de evaluate : 3.484 s
# Total sent this round (INT8): 11.287 MB
#
# Round 109
# Time evaluation
# loss: 3.7713, acc: 0.3031
# Durée de evaluate : 3.487 s
# Total sent this round (INT8): 11.287 MB
#
# Round 110
# Time evaluation
# loss: 2.1577, acc: 0.3563
# Durée de evaluate : 3.460 s
# Total sent this round (INT8): 33.860 MB
#
# Round 111
# Time evaluation
# loss: 2.3459, acc: 0.3201
# Durée de evaluate : 3.460 s
# Total sent this round (INT8): 33.860 MB
#
# Round 112
# No client participated this round — keeping global model.
#
# Round 113
# Time evaluation
# loss: 4.1468, acc: 0.2148
# Durée de evaluate : 3.418 s
# Total sent this round (INT8): 11.287 MB
#
# Round 114
# Time evaluation
# loss: 4.0178, acc: 0.1445
# Durée de evaluate : 3.613 s
# Total sent this round (INT8): 11.287 MB
#
# Round 115
# Time evaluation
# loss: 2.3109, acc: 0.3072
# Durée de evaluate : 3.981 s
# Total sent this round (INT8): 33.860 MB
#
# Round 116
# Time evaluation
# loss: 1.9710, acc: 0.3026
# Durée de evaluate : 3.466 s
# Total sent this round (INT8): 45.147 MB
#
# Round 117
# Time evaluation
# loss: 2.0695, acc: 0.4505
# Durée de evaluate : 3.471 s
# Total sent this round (INT8): 22.573 MB
#
# Round 118
# Time evaluation
# loss: 1.8590, acc: 0.4798
# Durée de evaluate : 3.460 s
# Total sent this round (INT8): 33.860 MB
# New best model saved (acc=0.4798)
#
# Round 119
# Time evaluation
# loss: 3.9048, acc: 0.2177
# Durée de evaluate : 3.670 s
# Total sent this round (INT8): 11.287 MB
#
# Round 120
# Time evaluation
# loss: 2.3631, acc: 0.4003
# Durée de evaluate : 3.949 s
# Total sent this round (INT8): 33.860 MB
#
# Round 121
# No client participated this round — keeping global model.
#
# Round 122
# Time evaluation
# loss: 1.8320, acc: 0.4232
# Durée de evaluate : 4.049 s
# Total sent this round (INT8): 33.860 MB
#
# Round 123
# Time evaluation
# loss: 1.9119, acc: 0.3746
# Durée de evaluate : 3.524 s
# Total sent this round (INT8): 22.573 MB
#
# Round 124
# Time evaluation
# loss: 2.2933, acc: 0.3489
# Durée de evaluate : 3.432 s
# Total sent this round (INT8): 22.573 MB
#
# Round 125
# Time evaluation
# loss: 3.3808, acc: 0.3231
# Durée de evaluate : 3.642 s
# Total sent this round (INT8): 11.287 MB
#
# Round 126
# Time evaluation
# loss: 2.0429, acc: 0.4699
# Durée de evaluate : 4.042 s
# Total sent this round (INT8): 33.860 MB
#
# Round 127
# No client participated this round — keeping global model.
#
# Round 128
# Time evaluation
# loss: 5.8848, acc: 0.1752
# Durée de evaluate : 3.477 s
# Total sent this round (INT8): 11.287 MB
#
# Round 129
# Time evaluation
# loss: 1.9307, acc: 0.4215
# Durée de evaluate : 4.091 s
# Total sent this round (INT8): 33.860 MB
#
# Round 130
# Time evaluation
# loss: 2.9269, acc: 0.3153
# Durée de evaluate : 3.475 s
# Total sent this round (INT8): 11.287 MB
#
# Round 131
# Time evaluation
# loss: 4.0887, acc: 0.1986
# Durée de evaluate : 3.855 s
# Total sent this round (INT8): 11.287 MB
#
# Round 132
# Time evaluation
# loss: 4.4236, acc: 0.2025
# Durée de evaluate : 3.475 s
# Total sent this round (INT8): 11.287 MB
#
# Round 133
# Time evaluation
# loss: 2.7115, acc: 0.4315
# Durée de evaluate : 3.421 s
# Total sent this round (INT8): 22.573 MB
#
# Round 134
# Time evaluation
# loss: 3.2919, acc: 0.4286
# Durée de evaluate : 3.502 s
# Total sent this round (INT8): 22.573 MB
#
# Round 135
# No client participated this round — keeping global model.
#
# Round 136
# No client participated this round — keeping global model.
#
# Round 137
# Time evaluation
# loss: 2.8252, acc: 0.3252
# Durée de evaluate : 3.436 s
# Total sent this round (INT8): 33.860 MB
#
# Round 138
# Time evaluation
# loss: 2.3872, acc: 0.3835
# Durée de evaluate : 3.464 s
# Total sent this round (INT8): 22.573 MB
#
# Round 139
# Time evaluation
# loss: 2.9447, acc: 0.2951
# Durée de evaluate : 3.477 s
# Total sent this round (INT8): 11.287 MB
#
# Round 140
# No client participated this round — keeping global model.
#
# Round 141
# No client participated this round — keeping global model.
#
# Round 142
# Time evaluation
# loss: 3.0097, acc: 0.3508
# Durée de evaluate : 3.618 s
# Total sent this round (INT8): 11.287 MB
#
# Round 143
# Time evaluation
# loss: 2.0486, acc: 0.3490
# Durée de evaluate : 3.994 s
# Total sent this round (INT8): 33.860 MB
#
# Round 144
# Time evaluation
# loss: 2.6705, acc: 0.3613
# Durée de evaluate : 3.531 s
# Total sent this round (INT8): 33.860 MB
#
# Round 145
# Time evaluation
# loss: 4.3172, acc: 0.2154
# Durée de evaluate : 3.534 s
# Total sent this round (INT8): 11.287 MB
#
# Round 146
# No client participated this round — keeping global model.
#
# Round 147
# Time evaluation
# loss: 1.6536, acc: 0.4154
# Durée de evaluate : 4.020 s
# Total sent this round (INT8): 56.433 MB
#
# Round 148
# Time evaluation
# loss: 1.3567, acc: 0.4806
# Durée de evaluate : 3.480 s
# Total sent this round (INT8): 56.433 MB
# New best model saved (acc=0.4806)
#
# Round 149
# No client participated this round — keeping global model.
#
# Round 150
# Time evaluation
# loss: 1.7519, acc: 0.4399
# Durée de evaluate : 3.948 s
# Total sent this round (INT8): 45.147 MB
# INT8 model update size: 11.287 MB
#
# Round 151
# Time evaluation
# loss: 3.7994, acc: 0.3294
# Durée de evaluate : 3.691 s
# Total sent this round (INT8): 22.573 MB
#
# Round 152
# No client participated this round — keeping global model.
#
# Round 153
# Time evaluation
# loss: 1.8807, acc: 0.4759
# Durée de evaluate : 3.451 s
# Total sent this round (INT8): 45.147 MB
#
# Round 154
# Time evaluation
# loss: 3.8218, acc: 0.2251
# Durée de evaluate : 4.071 s
# Total sent this round (INT8): 11.287 MB
#
# Round 155
# Time evaluation
# loss: 4.0101, acc: 0.2702
# Durée de evaluate : 3.496 s
# Total sent this round (INT8): 11.287 MB
#
# Round 156
# Time evaluation
# loss: 5.9254, acc: 0.1740
# Durée de evaluate : 3.983 s
# Total sent this round (INT8): 11.287 MB
#
# Round 157
# Time evaluation
# loss: 1.8826, acc: 0.3805
# Durée de evaluate : 3.475 s
# Total sent this round (INT8): 45.147 MB
#
# Round 158
# Time evaluation
# loss: 2.8612, acc: 0.3521
# Durée de evaluate : 3.600 s
# Total sent this round (INT8): 11.287 MB
#
# Round 159
# Time evaluation
# loss: 2.3789, acc: 0.2501
# Durée de evaluate : 3.993 s
# Total sent this round (INT8): 22.573 MB
#
# Round 160
# Time evaluation
# loss: 3.4701, acc: 0.1960
# Durée de evaluate : 3.566 s
# Total sent this round (INT8): 11.287 MB
#
# Round 161
# Time evaluation
# loss: 2.9802, acc: 0.2099
# Durée de evaluate : 3.472 s
# Total sent this round (INT8): 11.287 MB
#
# Round 162
# No client participated this round — keeping global model.
#
# Round 163
# Time evaluation
# loss: 4.1707, acc: 0.1806
# Durée de evaluate : 4.009 s
# Total sent this round (INT8): 11.287 MB
#
# Round 164
# Time evaluation
# loss: 3.3224, acc: 0.1700
# Durée de evaluate : 3.448 s
# Total sent this round (INT8): 11.287 MB
#
# Round 165
# No client participated this round — keeping global model.
#
# Round 166
# Time evaluation
# loss: 2.6562, acc: 0.1893
# Durée de evaluate : 3.715 s
# Total sent this round (INT8): 11.287 MB
#
# Round 167
# No client participated this round — keeping global model.
#
# Round 168
# Time evaluation
# loss: 2.5051, acc: 0.2651
# Durée de evaluate : 3.506 s
# Total sent this round (INT8): 22.573 MB
#
# Round 169
# Time evaluation
# loss: 2.7318, acc: 0.3194
# Durée de evaluate : 3.748 s
# Total sent this round (INT8): 11.287 MB
#
# Round 170
# Time evaluation
# loss: 1.6820, acc: 0.4774
# Durée de evaluate : 3.840 s
# Total sent this round (INT8): 22.573 MB
#
# Round 171
# No client participated this round — keeping global model.
#
# Round 172
# Time evaluation
# loss: 5.0558, acc: 0.1769
# Durée de evaluate : 3.461 s
# Total sent this round (INT8): 11.287 MB
#
# Round 173
# Time evaluation
# loss: 1.6626, acc: 0.4787
# Durée de evaluate : 3.548 s
# Total sent this round (INT8): 45.147 MB
#
# Round 174
# Time evaluation
# loss: 2.5298, acc: 0.3725
# Durée de evaluate : 3.447 s
# Total sent this round (INT8): 22.573 MB
#
# Round 175
# Time evaluation
# loss: 1.6082, acc: 0.4774
# Durée de evaluate : 3.888 s
# Total sent this round (INT8): 33.860 MB
#
# Round 176
# Time evaluation
# loss: 1.9439, acc: 0.4256
# Durée de evaluate : 3.563 s
# Total sent this round (INT8): 33.860 MB
#
# Round 177
# Time evaluation
# loss: 4.1841, acc: 0.2284
# Durée de evaluate : 3.441 s
# Total sent this round (INT8): 11.287 MB
#
# Round 178
# Time evaluation
# loss: 2.5664, acc: 0.3303
# Durée de evaluate : 3.521 s
# Total sent this round (INT8): 22.573 MB
#
# Round 179
# Time evaluation
# loss: 2.7833, acc: 0.3350
# Durée de evaluate : 3.454 s
# Total sent this round (INT8): 22.573 MB
#
# Round 180
# Time evaluation
# loss: 2.1801, acc: 0.3770
# Durée de evaluate : 3.473 s
# Total sent this round (INT8): 22.573 MB
#
# Round 181
# Time evaluation
# loss: 2.4200, acc: 0.2344
# Durée de evaluate : 4.053 s
# Total sent this round (INT8): 22.573 MB
#
# Round 182
# No client participated this round — keeping global model.
#
# Round 183
# Time evaluation
# loss: 1.5633, acc: 0.4133
# Durée de evaluate : 3.439 s
# Total sent this round (INT8): 45.147 MB
#
# Round 184
# Time evaluation
# loss: 5.5283, acc: 0.1821
# Durée de evaluate : 3.589 s
# Total sent this round (INT8): 11.287 MB
#
# Round 185
# Time evaluation
# loss: 1.3952, acc: 0.4883
# Durée de evaluate : 3.442 s
# Total sent this round (INT8): 45.147 MB
# New best model saved (acc=0.4883)
#
# Round 186
# Time evaluation
# loss: 2.8735, acc: 0.4837
# Durée de evaluate : 3.493 s
# Total sent this round (INT8): 11.287 MB
#
# Round 187
# Time evaluation
# loss: 1.7307, acc: 0.4577
# Durée de evaluate : 3.459 s
# Total sent this round (INT8): 45.147 MB
#
# Round 188
# Time evaluation
# loss: 1.6000, acc: 0.5033
# Durée de evaluate : 3.547 s
# Total sent this round (INT8): 45.147 MB
# New best model saved (acc=0.5033)
#
# Round 189
# Time evaluation
# loss: 2.1133, acc: 0.3641
# Durée de evaluate : 3.755 s
# Total sent this round (INT8): 22.573 MB
#
# Round 190
# Time evaluation
# loss: 1.5399, acc: 0.4412
# Durée de evaluate : 3.863 s
# Total sent this round (INT8): 33.860 MB
#
# Round 191
# Time evaluation
# loss: 3.8644, acc: 0.3405
# Durée de evaluate : 3.500 s
# Total sent this round (INT8): 11.287 MB
#
# Round 192
# Time evaluation
# loss: 3.0703, acc: 0.3425
# Durée de evaluate : 3.483 s
# Total sent this round (INT8): 11.287 MB
#
# Round 193
# Time evaluation
# loss: 1.8036, acc: 0.3945
# Durée de evaluate : 3.509 s
# Total sent this round (INT8): 45.147 MB
#
# Round 194
# Time evaluation
# loss: 1.6663, acc: 0.5189
# Durée de evaluate : 3.915 s
# Total sent this round (INT8): 45.147 MB
# New best model saved (acc=0.5189)
#
# Round 195
# Time evaluation
# loss: 2.8408, acc: 0.4969
# Durée de evaluate : 3.969 s
# Total sent this round (INT8): 11.287 MB
#
# Round 196
# Time evaluation
# loss: 2.1151, acc: 0.3406
# Durée de evaluate : 3.998 s
# Total sent this round (INT8): 33.860 MB
#
# Round 197
# Time evaluation
# loss: 4.0645, acc: 0.2675
# Durée de evaluate : 3.430 s
# Total sent this round (INT8): 11.287 MB
#
# Round 198
# Time evaluation
# loss: 1.6237, acc: 0.4877
# Durée de evaluate : 3.985 s
# Total sent this round (INT8): 45.147 MB
#
# Round 199
# Time evaluation
# loss: 3.7911, acc: 0.3362
# Durée de evaluate : 3.939 s
# Total sent this round (INT8): 11.287 MB
#
# Round 200
# Time evaluation
# loss: 2.9439, acc: 0.3075
# Durée de evaluate : 3.412 s
# Total sent this round (INT8): 11.287 MB
# INT8 model update size: 11.287 MB
#
# Round 201
# Time evaluation
# loss: 2.4014, acc: 0.2712
# Durée de evaluate : 3.746 s
# Total sent this round (INT8): 33.860 MB
#
# Round 202
# Time evaluation
# loss: 3.0434, acc: 0.3484
# Durée de evaluate : 3.441 s
# Total sent this round (INT8): 11.287 MB
#
# Round 203
# Time evaluation
# loss: 3.2349, acc: 0.4756
# Durée de evaluate : 3.351 s
# Total sent this round (INT8): 11.287 MB
#
# Round 204
# Time evaluation
# loss: 1.9400, acc: 0.4981
# Durée de evaluate : 3.977 s
# Total sent this round (INT8): 45.147 MB
#
# Round 205
# Time evaluation
# loss: 2.0782, acc: 0.4120
# Durée de evaluate : 3.416 s
# Total sent this round (INT8): 22.573 MB
#
# Round 206
# Time evaluation
# loss: 1.4871, acc: 0.5108
# Durée de evaluate : 3.397 s
# Total sent this round (INT8): 33.860 MB
#
# Round 207
# Time evaluation
# loss: 1.8993, acc: 0.4052
# Durée de evaluate : 3.437 s
# Total sent this round (INT8): 33.860 MB
#
# Round 208
# Time evaluation
# loss: 1.3881, acc: 0.4870
# Durée de evaluate : 3.410 s
# Total sent this round (INT8): 56.433 MB
#
# Round 209
# Time evaluation
# loss: 5.4370, acc: 0.1786
# Durée de evaluate : 3.954 s
# Total sent this round (INT8): 22.573 MB
#
# Round 210
# Time evaluation
# loss: 3.4051, acc: 0.2743
# Durée de evaluate : 3.421 s
# Total sent this round (INT8): 22.573 MB
#
# Round 211
# Time evaluation
# loss: 2.9818, acc: 0.3545
# Durée de evaluate : 3.373 s
# Total sent this round (INT8): 11.287 MB
#
# Round 212
# Time evaluation
# loss: 2.5213, acc: 0.4389
# Durée de evaluate : 3.429 s
# Total sent this round (INT8): 22.573 MB
#
# Round 213
# Time evaluation
# loss: 1.3265, acc: 0.5046
# Durée de evaluate : 3.341 s
# Total sent this round (INT8): 45.147 MB
#
# Round 214
# Time evaluation
# loss: 2.6649, acc: 0.4873
# Durée de evaluate : 3.397 s
# Total sent this round (INT8): 11.287 MB
#
# Round 215
# Time evaluation
# loss: 1.9704, acc: 0.4005
# Durée de evaluate : 3.927 s
# Total sent this round (INT8): 22.573 MB
#
# Round 216
# Time evaluation
# loss: 3.9061, acc: 0.2859
# Durée de evaluate : 3.394 s
# Total sent this round (INT8): 11.287 MB
#
# Round 217
# Time evaluation
# loss: 1.5418, acc: 0.5041
# Durée de evaluate : 3.842 s
# Total sent this round (INT8): 33.860 MB
#
# Round 218
# Time evaluation
# loss: 2.1099, acc: 0.4735
# Durée de evaluate : 3.574 s
# Total sent this round (INT8): 22.573 MB
#
# Round 219
# Time evaluation
# loss: 3.4575, acc: 0.3387
# Durée de evaluate : 3.447 s
# Total sent this round (INT8): 11.287 MB
#
# Round 220
# Time evaluation
# loss: 2.1431, acc: 0.4393
# Durée de evaluate : 3.400 s
# Total sent this round (INT8): 22.573 MB
#
# Round 221
# Time evaluation
# loss: 3.3418, acc: 0.2904
# Durée de evaluate : 4.001 s
# Total sent this round (INT8): 22.573 MB
#
# Round 222
# Time evaluation
# loss: 3.9051, acc: 0.2079
# Durée de evaluate : 3.512 s
# Total sent this round (INT8): 11.287 MB
#
# Round 223
# No client participated this round — keeping global model.
#
# Round 224
# Time evaluation
# loss: 2.5185, acc: 0.3595
# Durée de evaluate : 3.996 s
# Total sent this round (INT8): 11.287 MB
#
# Round 225
# Time evaluation
# loss: 6.9052, acc: 0.1795
# Durée de evaluate : 3.425 s
# Total sent this round (INT8): 11.287 MB
#
# Round 226
# Time evaluation
# loss: 5.8127, acc: 0.1827
# Durée de evaluate : 3.961 s
# Total sent this round (INT8): 11.287 MB
#
# Round 227
# Time evaluation
# loss: 2.5929, acc: 0.4815
# Durée de evaluate : 3.948 s
# Total sent this round (INT8): 22.573 MB
#
# Round 228
# Time evaluation
# loss: 2.1784, acc: 0.3656
# Durée de evaluate : 4.019 s
# Total sent this round (INT8): 22.573 MB
#
# Round 229
# Time evaluation
# loss: 2.1744, acc: 0.3927
# Durée de evaluate : 3.631 s
# Total sent this round (INT8): 33.860 MB
#
# Round 230
# Time evaluation
# loss: 1.9295, acc: 0.4195
# Durée de evaluate : 3.472 s
# Total sent this round (INT8): 33.860 MB
#
# Round 231
# Time evaluation
# loss: 1.8214, acc: 0.4670
# Durée de evaluate : 3.959 s
# Total sent this round (INT8): 56.433 MB
#
# Round 232
# Time evaluation
# loss: 2.2348, acc: 0.5266
# Durée de evaluate : 3.977 s
# Total sent this round (INT8): 22.573 MB
# New best model saved (acc=0.5266)
#
# Round 233
# Time evaluation
# loss: 1.6590, acc: 0.4756
# Durée de evaluate : 3.483 s
# Total sent this round (INT8): 45.147 MB
#
# Round 234
# Time evaluation
# loss: 4.1282, acc: 0.2790
# Durée de evaluate : 3.841 s
# Total sent this round (INT8): 11.287 MB
#
# Round 235
# Time evaluation
# loss: 2.3286, acc: 0.3431
# Durée de evaluate : 3.832 s
# Total sent this round (INT8): 22.573 MB
#
# Round 236
# Time evaluation
# loss: 1.8710, acc: 0.4675
# Durée de evaluate : 3.508 s
# Total sent this round (INT8): 33.860 MB
#
# Round 237
# Time evaluation
# loss: 3.9372, acc: 0.3461
# Durée de evaluate : 3.481 s
# Total sent this round (INT8): 22.573 MB
#
# Round 238
# Time evaluation
# loss: 1.5007, acc: 0.5206
# Durée de evaluate : 3.983 s
# Total sent this round (INT8): 45.147 MB
#
# Round 239
# Time evaluation
# loss: 3.7087, acc: 0.3522
# Durée de evaluate : 4.047 s
# Total sent this round (INT8): 22.573 MB
#
# Round 240
# Time evaluation
# loss: 2.2343, acc: 0.3974
# Durée de evaluate : 3.553 s
# Total sent this round (INT8): 22.573 MB
#
# Round 241
# Time evaluation
# loss: 1.9525, acc: 0.3801
# Durée de evaluate : 4.068 s
# Total sent this round (INT8): 45.147 MB
#
# Round 242
# Time evaluation
# loss: 3.0679, acc: 0.3710
# Durée de evaluate : 3.433 s
# Total sent this round (INT8): 11.287 MB
#
# Round 243
# Time evaluation
# loss: 1.8798, acc: 0.5445
# Durée de evaluate : 3.524 s
# Total sent this round (INT8): 45.147 MB
# New best model saved (acc=0.5445)
#
# Round 244
# Time evaluation
# loss: 1.7298, acc: 0.4566
# Durée de evaluate : 3.491 s
# Total sent this round (INT8): 22.573 MB
#
# Round 245
# Time evaluation
# loss: 1.4237, acc: 0.5108
# Durée de evaluate : 3.505 s
# Total sent this round (INT8): 33.860 MB
#
# Round 246
# Time evaluation
# loss: 2.7650, acc: 0.2815
# Durée de evaluate : 3.410 s
# Total sent this round (INT8): 22.573 MB
#
# Round 247
# Time evaluation
# loss: 2.9858, acc: 0.4915
# Durée de evaluate : 3.988 s
# Total sent this round (INT8): 11.287 MB
#
# Round 248
# Time evaluation
# loss: 2.3407, acc: 0.3904
# Durée de evaluate : 3.766 s
# Total sent this round (INT8): 22.573 MB
#
# Round 249
# Time evaluation
# loss: 2.2491, acc: 0.2670
# Durée de evaluate : 3.499 s
# Total sent this round (INT8): 33.860 MB
#
# Round 250
# Time evaluation
# loss: 8.6218, acc: 0.1808
# Durée de evaluate : 3.474 s
# Total sent this round (INT8): 11.287 MB
# INT8 model update size: 11.287 MB
#
# Round 251
# Time evaluation
# loss: 2.2750, acc: 0.5185
# Durée de evaluate : 3.491 s
# Total sent this round (INT8): 33.860 MB
#
# Round 252
# Time evaluation
# loss: 1.5531, acc: 0.5265
# Durée de evaluate : 4.025 s
# Total sent this round (INT8): 45.147 MB
#
# Round 253
# Time evaluation
# loss: 1.2579, acc: 0.6026
# Durée de evaluate : 3.981 s
# Total sent this round (INT8): 56.433 MB
# New best model saved (acc=0.6026)
#
# Round 254
# Time evaluation
# loss: 2.8956, acc: 0.3704
# Durée de evaluate : 4.050 s
# Total sent this round (INT8): 22.573 MB
#
# Round 255
# Time evaluation
# loss: 2.4152, acc: 0.4274
# Durée de evaluate : 3.417 s
# Total sent this round (INT8): 22.573 MB
#
# Round 256
# Time evaluation
# loss: 2.8782, acc: 0.3578
# Durée de evaluate : 4.037 s
# Total sent this round (INT8): 33.860 MB
#
# Round 257
# Time evaluation
# loss: 3.0723, acc: 0.3709
# Durée de evaluate : 3.392 s
# Total sent this round (INT8): 11.287 MB
#
# Round 258
# No client participated this round — keeping global model.
#
# Round 259
# Time evaluation
# loss: 1.4158, acc: 0.5406
# Durée de evaluate : 3.530 s
# Total sent this round (INT8): 45.147 MB
#
# Round 260
# Time evaluation
# loss: 4.1532, acc: 0.3391
# Durée de evaluate : 4.005 s
# Total sent this round (INT8): 11.287 MB
#
# Round 261
# Time evaluation
# loss: 1.6533, acc: 0.5186
# Durée de evaluate : 3.465 s
# Total sent this round (INT8): 22.573 MB
#
# Round 262
# Time evaluation
# loss: 2.3851, acc: 0.5149
# Durée de evaluate : 3.492 s
# Total sent this round (INT8): 33.860 MB
#
# Round 263
# No client participated this round — keeping global model.
#
# Round 264
# Time evaluation
# loss: 2.1001, acc: 0.5097
# Durée de evaluate : 3.566 s
# Total sent this round (INT8): 33.860 MB
#
# Round 265
# Time evaluation
# loss: 2.4850, acc: 0.3874
# Durée de evaluate : 3.821 s
# Total sent this round (INT8): 33.860 MB
#
# Round 266
# Time evaluation
# loss: 4.5087, acc: 0.3452
# Durée de evaluate : 3.464 s
# Total sent this round (INT8): 11.287 MB
#
# Round 267
# Time evaluation
# loss: 2.0758, acc: 0.5065
# Durée de evaluate : 4.027 s
# Total sent this round (INT8): 33.860 MB
#
# Round 268
# No client participated this round — keeping global model.
#
# Round 269
# Time evaluation
# loss: 2.8158, acc: 0.3758
# Durée de evaluate : 3.522 s
# Total sent this round (INT8): 11.287 MB
#
# Round 270
# Time evaluation
# loss: 1.9767, acc: 0.4410
# Durée de evaluate : 3.483 s
# Total sent this round (INT8): 22.573 MB
#
# Round 271
# Time evaluation
# loss: 1.7122, acc: 0.4520
# Durée de evaluate : 3.666 s
# Total sent this round (INT8): 22.573 MB
#
# Round 272
# Time evaluation
# loss: 3.6771, acc: 0.2262
# Durée de evaluate : 3.810 s
# Total sent this round (INT8): 22.573 MB
#
# Round 273
# Time evaluation
# loss: 2.2815, acc: 0.3674
# Durée de evaluate : 3.450 s
# Total sent this round (INT8): 33.860 MB
#
# Round 274
# Time evaluation
# loss: 2.0711, acc: 0.4216
# Durée de evaluate : 3.452 s
# Total sent this round (INT8): 33.860 MB
#
# Round 275
# Time evaluation
# loss: 1.4635, acc: 0.5626
# Durée de evaluate : 4.042 s
# Total sent this round (INT8): 33.860 MB
#
# Round 276
# Time evaluation
# loss: 2.4502, acc: 0.5113
# Durée de evaluate : 4.055 s
# Total sent this round (INT8): 22.573 MB
#
# Round 277
# Time evaluation
# loss: 1.7354, acc: 0.4466
# Durée de evaluate : 3.863 s
# Total sent this round (INT8): 33.860 MB
#
# Round 278
# Time evaluation
# loss: 1.7637, acc: 0.4676
# Durée de evaluate : 3.791 s
# Total sent this round (INT8): 45.147 MB
#
# Round 279
# Time evaluation
# loss: 3.6613, acc: 0.3454
# Durée de evaluate : 3.462 s
# Total sent this round (INT8): 22.573 MB
#
# Round 280
# Time evaluation
# loss: 1.3432, acc: 0.5389
# Durée de evaluate : 3.949 s
# Total sent this round (INT8): 56.433 MB
#
# Round 281
# Time evaluation
# loss: 2.9787, acc: 0.3557
# Durée de evaluate : 3.946 s
# Total sent this round (INT8): 22.573 MB
#
# Round 282
# Time evaluation
# loss: 3.4700, acc: 0.2991
# Durée de evaluate : 3.377 s
# Total sent this round (INT8): 11.287 MB
#
# Round 283
# Time evaluation
# loss: 2.9843, acc: 0.3798
# Durée de evaluate : 3.554 s
# Total sent this round (INT8): 11.287 MB
#
# Round 284
# Time evaluation
# loss: 1.7550, acc: 0.4344
# Durée de evaluate : 3.423 s
# Total sent this round (INT8): 33.860 MB
#
# Round 285
# Time evaluation
# loss: 2.3074, acc: 0.3934
# Durée de evaluate : 3.477 s
# Total sent this round (INT8): 22.573 MB
#
# Round 286
# Time evaluation
# loss: 1.4371, acc: 0.4979
# Durée de evaluate : 3.508 s
# Total sent this round (INT8): 56.433 MB
#
# Round 287
# No client participated this round — keeping global model.
#
# Round 288
# Time evaluation
# loss: 4.0300, acc: 0.2965
# Durée de evaluate : 3.936 s
# Total sent this round (INT8): 11.287 MB
#
# Round 289
# Time evaluation
# loss: 3.0729, acc: 0.4925
# Durée de evaluate : 4.193 s
# Total sent this round (INT8): 11.287 MB
#
# Round 290
# No client participated this round — keeping global model.
#
# Round 291
# Time evaluation
# loss: 3.6042, acc: 0.2925
# Durée de evaluate : 3.499 s
# Total sent this round (INT8): 11.287 MB
#
# Round 292
# Time evaluation
# loss: 4.1452, acc: 0.2653
# Durée de evaluate : 3.972 s
# Total sent this round (INT8): 11.287 MB
#
# Round 293
# Time evaluation
# loss: 2.8495, acc: 0.5099
# Durée de evaluate : 3.547 s
# Total sent this round (INT8): 22.573 MB
#
# Round 294
# Time evaluation
# loss: 2.1977, acc: 0.4254
# Durée de evaluate : 3.800 s
# Total sent this round (INT8): 45.147 MB
#
# Round 295
# Time evaluation
# loss: 1.8125, acc: 0.4696
# Durée de evaluate : 4.140 s
# Total sent this round (INT8): 33.860 MB
#
# Round 296
# Time evaluation
# loss: 1.6968, acc: 0.4335
# Durée de evaluate : 4.005 s
# Total sent this round (INT8): 33.860 MB
#
# Round 297
# Time evaluation
# loss: 1.4060, acc: 0.5442
# Durée de evaluate : 3.420 s
# Total sent this round (INT8): 33.860 MB
#
# Round 298
# Time evaluation
# loss: 4.0065, acc: 0.3378
# Durée de evaluate : 3.501 s
# Total sent this round (INT8): 11.287 MB
#
# Round 299
# No client participated this round — keeping global model.
#
# Round 300
# Time evaluation
# loss: 2.6982, acc: 0.4969
# Durée de evaluate : 3.886 s
# Total sent this round (INT8): 22.573 MB
# INT8 model update size: 11.287 MB
# Final model saved

# %%
# Plot metrics
metrics_filename = "training_metrics.png"
plot_metrics(metrics, metrics_filename)
# Out:
# Plot saved to training_metrics.png

# %%
# Compute summary statistics
summary_filename = "summary.json"
summary = summarize_metrics(metrics, summary_filename)
# Out:
# === Training Summary ===
# Final loss: 2.6982
# Best loss: 1.2579
# Final accuracy: 0.4969
# Best accuracy: 0.6026
# Best loss round: 253
# Best accuracy round: 253
#
# Mean round time: 6.968 s
# Std round time: 4.375 s
# Total training time: 1867.314 s
#
# Initial model size: 44.805 MB
# Final model size: 44.805 MB
# Model size at best accuracy: 44.805 MB
# Model size at best loss: 44.805 MB
#
# Size reduction (final): 0.000 MB (0.00%)
# Size reduction (best accuracy): 0.000 MB (0.00%)
# Size reduction (best loss): 0.000 MB (0.00%)
#
# Accuracy per MB: 0.0134
#
# Summary saved to summary.json

# %%
# !zip -r /content/{run_save_dir}.zip /content/{run_save_dir}/
from google.colab import files
files.download(f"/content/{run_save_dir}.zip")
files.download(f"/content/{metrics_filename}")
files.download(f"/content/{summary_filename}")
# Out:
#   adding: content/checkpoints/ (stored 0%)
#   adding: content/checkpoints/best_model.pth (deflated 44%)
