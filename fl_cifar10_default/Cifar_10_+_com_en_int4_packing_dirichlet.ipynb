# %%
# Import modules
import os
import sys
import torch
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
import torch.nn as nn
import torch.optim as optim
import random
import torch.nn.functional as F
import copy
import matplotlib.pyplot as plt
import numpy as np
import time
import io
import json

# %% [markdown]
# **Obtention de la dernière version de torchao**

# %%
# !pip install -U torchao
# Out:
# Requirement already satisfied: torchao in /usr/local/lib/python3.12/dist-packages (0.10.0)
# Collecting torchao
#   Downloading torchao-0.15.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Downloading torchao-0.15.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 81.3 MB/s eta 0:00:00
# Installing collected packages: torchao
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# Successfully installed torchao-0.15.0

# %%
pip show torchao
# Out:
# Name: torchao
# Version: 0.15.0
# Summary: Package for applying ao techniques to GPU models
# Home-page: https://github.com/pytorch/ao
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires:
# Required-by:

# %%
#Import modules for quantization
from torchao.quantization import quantize_, Int4WeightOnlyConfig
from torchao.quantization.qat import QATConfig
# Out:
# WARNING:torchao:Skipping import of cpp extensions due to incompatible torch version 2.9.0+cu126 for torchao version 0.15.0             Please see https://github.com/pytorch/ao/issues/2919 for more info

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Load CIFAR-10 Dataset
d = './data'
if not os.path.exists(d):
    os.mkdir(d)

train_transforms = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2470, 0.2435, 0.2616))
])
test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465),
                         (0.2470, 0.2435, 0.2616))
])

train_set = datasets.CIFAR10(root=d, train=True, transform=train_transforms, download=True)
test_set = datasets.CIFAR10(root=d, train=False, transform=test_transforms, download=True)

batch_size = 32
global_train_loader = torch.utils.data.DataLoader(
                 dataset=train_set,
                 batch_size=batch_size,
                 shuffle=True)
global_test_loader = torch.utils.data.DataLoader(
                dataset=test_set,
                batch_size=batch_size,
                shuffle=False)
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 48.5MB/s]

# %%
from collections import defaultdict
from torch.utils.data import Subset, DataLoader
from collections import Counter
import matplotlib.pyplot as plt


def Dirichlet(labels, alpha, num_clients) :
    n_classes = len(np.unique(labels))
    client_indices = defaultdict(list)
    labels = np.array(train_set.targets)

    np.random.seed(42)
    torch.manual_seed(42)

    for c in range(n_classes):
        labels = np.array(train_set.targets)
        idx = np.where(labels == c)[0]
        print("Voici le nombre de labels dans la classe", c, ":", len(idx), "et les indices sont", idx )
        np.random.shuffle(idx)
        proportions = np.random.dirichlet([alpha] * num_clients)
        proportions = (np.cumsum(proportions) * len(idx)).astype(int)[:-1]
        splits = np.split(idx, proportions)


        for client_id, split in enumerate(splits):
            client_indices[client_id].extend(split)

    for cid in range(num_clients):
        if len(client_indices[cid]) == 0:
            random_idx = np.random.randint(0, len(labels))
            client_indices[cid].append(random_idx)
            print(f"Warning: Client {cid} était vide, un échantillon a été ajouté.")


    return client_indices



def count_labels_per_client(train_set, client_indices, num_classes=10):
    counts = np.zeros((len(client_indices), num_classes), dtype=int)

    for cid, indices in client_indices.items():
        labels = np.array(train_set.targets)[indices]
        counter = Counter(labels)
        for cls, cnt in counter.items():
            counts[cid, cls] = cnt

    return counts


def plot_label_distribution(counts):
    plt.figure(figsize=(10, 6))
    plt.imshow(counts, aspect="auto")
    plt.colorbar(label="Number of samples")
    plt.xlabel("Class label")
    plt.ylabel("Client ID")
    plt.title("Label distribution per client (Dirichlet non-IID)")
    plt.tight_layout()
    plt.show()



def build_client_datasets(
    num_clients=10,
    alpha=0.5,
    batch_size=32,
):

    labels = train_set.targets
    client_indices = Dirichlet(labels, alpha, num_clients)

    counts = count_labels_per_client(train_set, client_indices, num_classes=10)
    print(counts)
    counts_norm = counts / counts.sum(axis=1, keepdims=True)
    plot_label_distribution(counts_norm)

    i = 0
    clients = []

    for cid, indices in client_indices.items():

        model = models.resnet18(weights=None, num_classes=10).to(device)

        number_sample = 0
        for j in range (len(counts[i])) :
          number_sample += counts[i][j]


        loader = torch.utils.data.DataLoader(
                  dataset= Subset(train_set, indices) ,
                  batch_size=batch_size,
                  shuffle=True,
                  drop_last=True) #supprime le batch s'il fait moinsde 32 images j'en avais besoin pour éviter des erreurs de batch de size 1

        client = {"client_id": i,
            "local_dataset": loader,
            "local_model" : model,
            "optimizer": optim.SGD(model.parameters(), lr=0.01, momentum=0.9),
            "number_sample" : number_sample}

        clients.append(client)
        i += 1


    return clients


clients = build_client_datasets(    num_clients=10,
    alpha=65,
    batch_size=32)

number_sample_clients = [x["number_sample"] for x in clients]
print(number_sample_clients)
# Out:
# Voici le nombre de labels dans la classe 0 : 5000 et les indices sont [   29    30    35 ... 49941 49992 49994]
# Voici le nombre de labels dans la classe 1 : 5000 et les indices sont [    4     5    32 ... 49993 49998 49999]
# Voici le nombre de labels dans la classe 2 : 5000 et les indices sont [    6    13    18 ... 49987 49991 49995]
# Voici le nombre de labels dans la classe 3 : 5000 et les indices sont [    9    17    21 ... 49979 49982 49983]
# Voici le nombre de labels dans la classe 4 : 5000 et les indices sont [    3    10    20 ... 49981 49984 49990]
# Voici le nombre de labels dans la classe 5 : 5000 et les indices sont [   27    40    51 ... 49964 49980 49988]
# Voici le nombre de labels dans la classe 6 : 5000 et les indices sont [    0    19    22 ... 49962 49966 49996]
# Voici le nombre de labels dans la classe 7 : 5000 et les indices sont [    7    11    12 ... 49965 49978 49986]
# Voici le nombre de labels dans la classe 8 : 5000 et les indices sont [    8    62    69 ... 49968 49976 49985]
# Voici le nombre de labels dans la classe 9 : 5000 et les indices sont [    1     2    14 ... 49963 49971 49997]
# [[593 509 492 454 500 490 457 425 504 490]
#  [525 399 671 564 559 661 562 460 485 534]
#  [484 511 458 567 447 545 434 463 547 461]
#  [485 523 451 393 475 487 454 487 459 462]
#  [541 485 538 640 587 509 546 485 502 561]
#  [426 426 463 578 468 476 505 553 507 501]
#  [437 556 439 416 459 411 568 504 520 487]
#  [382 478 481 496 456 482 408 523 480 465]
#  [547 572 463 404 544 470 578 507 456 521]
#  [580 541 544 488 505 469 488 593 540 518]]
# [np.int64(4914), np.int64(5420), np.int64(4917), np.int64(4676), np.int64(5394), np.int64(4903), np.int64(4797), np.int64(4651), np.int64(5062), np.int64(5266)]

# %%
import torch

def packing(tensor_high, tensor_low) :

    packed_value = (tensor_high.to(torch.int8) << 4) | (tensor_low.to(torch.int8) & 0x0F)
    return packed_value

def unpacking(packed_value):
    LOW_MASK = 0x0F

    tensor_high = packed_value >> 4
    tensor_low = packed_value & LOW_MASK
    def sign_correct(x):
        # Si la valeur est entre 8 et 15 (c-à-d 1000 à 1111), c'est une valeur INT4 négative
        return torch.where(x > 7, x - 16, x).to(torch.int8)

    return sign_correct(tensor_high), sign_correct(tensor_low)


def quantize_tensor(tensor, bits=4):

    qmin = -(2 ** (bits - 1))
    qmax = (2 ** (bits - 1)) - 1
    max_val = tensor.abs().max()
    scale = max_val / qmax if max_val != 0 else 1.0
    q_tensor = (tensor / scale).round().clamp(qmin, qmax).to(torch.int8)
    return q_tensor, scale


def quantize_model_state_dict(state_dict, bits=4):
    q_state = {}
    scales = {}
    original_shape = {}
    original_numel = {}

    for name, tensor in state_dict.items():
        if "bn" in name or "bias" in name or tensor.dim() < 2:
            q_state[name] = tensor
            scales[name] = None
        elif tensor.dtype == torch.float32:
            q_tensor_unpacked, scale = quantize_tensor(tensor, bits)
            L = q_tensor_unpacked.numel()
            needs_padding = L % 2 != 0
            if needs_padding:
                q_tensor_unpacked = torch.cat([q_tensor_unpacked.flatten(),
                                               torch.tensor([0], dtype=torch.int8, device=tensor.device)])

            q_low = q_tensor_unpacked[::2]
            q_high = q_tensor_unpacked[1::2]

            q_tensor_packed = packing(q_high, q_low)

            q_state[name] = q_tensor_packed.reshape(-1)
            scales[name] = scale
        else:
            q_state[name] = tensor
            scales[name] = None

        original_shape[name] = tensor.shape
        original_numel[name] = tensor.numel()

    return q_state, scales, original_shape, original_numel


def dequantize_tensor_packed(q_tensor_packed, scale, original_numel=None):

    q_high, q_low = unpacking(q_tensor_packed)

    L_unpacked = q_high.numel() + q_low.numel()
    q_tensor_unpacked = torch.empty(L_unpacked, dtype=torch.int8, device=q_tensor_packed.device)

    q_tensor_unpacked[::2] = q_low
    q_tensor_unpacked[1::2] = q_high

    if original_numel is not None and original_numel < L_unpacked:
        q_tensor_unpacked = q_tensor_unpacked[:original_numel]

    return q_tensor_unpacked.float() * scale


def dequantize_model_state_dict(q_state, scales, original_shapes, original_numel):

    fp32_state = {}

    for name, q_tensor_packed in q_state.items():
        scale = scales.get(name)
        original_shape = original_shapes[name]

        if scale is not None:

            original_numel_tensor = original_numel[name]

            fp32_tensor = dequantize_tensor_packed(q_tensor_packed, scale, original_numel_tensor)

            fp32_state[name] = fp32_tensor.reshape(original_shape)
        else:
            fp32_state[name] = q_tensor_packed

    return fp32_state

# %%
def client_load_model(client, model):
    client["local_model"].load_state_dict(model.state_dict())

def client_local_training(client):
    criterion = nn.CrossEntropyLoss()
    optimizer = client["optimizer"]
    dataset = client["local_dataset"]
    model = client["local_model"].to(device)
    model.train()

    for batch_idx, (x, target) in enumerate(dataset):
        x, target = x.to(device), target.to(device)
        out = model(x)
        loss = criterion(out, target)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    return client["local_model"].state_dict()

def client_send_update(client, global_state_dict):
    local_state = client["local_model"].state_dict()
    delta_state = {}

    with torch.no_grad():
        for name in local_state.keys():
            delta_state[name] = local_state[name] - global_state_dict[name].to(device)
    q_state, scales, original_shape, original_numel = quantize_model_state_dict(delta_state)
    return q_state, scales, original_shape, original_numel

def server_aggregate_quantized(global_model, q_updates):

    current_global_state = global_model.state_dict()
    sum_deltas = {name: torch.zeros_like(param) for name, param in current_global_state.items()}

    for q_state, scales, original_shape, original_numel in q_updates:
        fp32_delta = dequantize_model_state_dict(q_state, scales, original_shape, original_numel)

        for name in sum_deltas:
            sum_deltas[name] += fp32_delta[name].to(device)

    new_global_state = {}
    n = len(q_updates)
    for name in current_global_state:
        new_global_state[name] = current_global_state[name] + (sum_deltas[name] / n)

    return new_global_state

def evaluate(model, dataset):
    model.to(device)
    model.eval()
    criterion = nn.CrossEntropyLoss()
    total_loss, total, correct = 0, 0, 0

    with torch.no_grad():
        for x, target in dataset:
            x, target = x.to(device), target.to(device)
            out = model(x)
            loss = criterion(out, target)
            _, pred_label = torch.max(out, 1)
            total_loss += loss.item()
            total += x.size(0)
            correct += (pred_label == target).sum().item()

    avg_loss = total_loss / len(dataset)
    acc = correct / total
    print(f"loss: {avg_loss:.4f}, acc: {acc:.4f}")
    return avg_loss, acc

def get_model_size(model):
    buffer = io.BytesIO()
    torch.save(model.state_dict(), buffer)
    size_MB = buffer.getbuffer().nbytes / 1e6
    return size_MB

def get_quantized_model_size(q_state):
    buffer = io.BytesIO()
    torch.save(q_state, buffer)
    size_MB = buffer.getbuffer().nbytes / 1e6
    return size_MB

def federated_learning_loop_int8(save_dir):
    # Set seed
    torch.manual_seed(42)
    global_model = models.resnet18(weights=None, num_classes=10).to(device)

    client_participation_fraction = 0.2
    rounds = 750
    eval_interval = 10  # Measure costly metrics every X rounds
    save_interval = 50  # Save model every Y rounds
    os.makedirs(save_dir, exist_ok=True)

    metrics = {
        "round": [],
        "loss": [],
        "accuracy": [],
        "round_time": [],
        "model_size": []
    }
    best_acc = 0.0

    for r in range(rounds):
        print(f"\nRound {r+1}")

        # Start the timer
        start_time = time.time()

        # Broadcast global model to clients
        for c in clients:
            client_load_model(c, global_model)

        q_updates = []

        # Selected clients perform local training
        initial_global_state = copy.deepcopy(global_model.state_dict())

        for c in clients:
            if random.random() <= client_participation_fraction:
                client_local_training(c)
                # On passe initial_global_state pour calculer le delta
                q_updates.append(client_send_update(c, initial_global_state))


        # Aggregate models from participating clients
        if len(q_updates) == 0:
          print("No client participated this round — keeping global model.")
          aggregated_model = global_model.state_dict()
        else:
          aggregated_model = server_aggregate_quantized(global_model, q_updates)
          global_model.load_state_dict(aggregated_model)

        # Update global model
        global_model.load_state_dict(aggregated_model)

        # Stop the timer before computing the metrics
        round_time = time.time() - start_time

        # Evaluation
        print("Time evaluation")
        t0 = time.time()
        loss, acc = evaluate(global_model, global_test_loader)
        t1 = time.time()
        print(f"Durée de evaluate : {t1 - t0:.3f} s")

        if (r + 1) % eval_interval == 0 or r == 0 or r == rounds - 1:
            model_size = get_model_size(global_model)
        else:
            model_size = metrics["model_size"][-1]

        # Save metrics for plotting
        metrics["round"].append(r+1)
        metrics["round_time"].append(round_time)
        metrics["loss"].append(loss)
        metrics["accuracy"].append(acc)
        metrics["model_size"].append(model_size)

        total_bytes = 0
        for q_state, scales, original_shape, original_numel in q_updates:
            buffer = io.BytesIO()
            torch.save(q_state, buffer)
            total_bytes += buffer.getbuffer().nbytes
        print(f"Total sent this round (INT4): {total_bytes/1e6:.3f} MB")

        # Save model periodically
        if (r + 1) % save_interval == 0:
          example_q_state, example_scales, original_shape, original_numel = client_send_update(clients[0], global_model.state_dict())
          quantized_size = get_quantized_model_size(example_q_state)
          print(f"INT4 model update size: {quantized_size:.3f} MB")

        # Save best model so far
        if acc > best_acc:
            best_acc = acc
            torch.save(global_model.state_dict(), f"{save_dir}/best_model.pth")
            print(f"New best model saved (acc={acc:.4f})")

    # Save final model
    #torch.save(global_model.state_dict(), f"{save_dir}/final_model.pth")
    print("Final model saved")

    return metrics

# %%
def plot_metrics(metrics, filename):
    rounds = np.array(metrics["round"])
    loss = np.array(metrics["loss"])
    acc = np.array(metrics["accuracy"])
    round_time = np.array(metrics["round_time"])
    model_size = np.array(metrics["model_size"])

    plt.style.use('seaborn-v0_8-paper')

    fig, axes = plt.subplots(2, 2, figsize=(12, 8))
    axes = axes.ravel()

    # Loss
    axes[0].plot(rounds, loss, color='tab:blue', linewidth=2)
    axes[0].set_title("Global Model Loss", fontsize=15)
    axes[0].set_xlabel("Round", fontsize=13)
    axes[0].set_ylabel("Loss", fontsize=13)
    axes[0].grid(True)

    # Accuracy
    axes[1].plot(rounds, acc, color='tab:orange', linewidth=2)
    axes[1].set_title("Global Model Accuracy", fontsize=15)
    axes[1].set_xlabel("Round", fontsize=13)
    axes[1].set_ylabel("Accuracy", fontsize=13)
    axes[1].grid(True)

    # Round time
    axes[2].plot(rounds, round_time, color='tab:green', linewidth=2)
    axes[2].set_title("Round Duration", fontsize=15)
    axes[2].set_xlabel("Round", fontsize=13)
    axes[2].set_ylabel("Time (s)", fontsize=13)
    axes[2].grid(True)

    # Model size
    axes[3].plot(rounds, model_size, color='tab:red', linewidth=2)
    axes[3].set_title("Model Size", fontsize=15)
    axes[3].set_xlabel("Round", fontsize=13)
    axes[3].set_ylabel("Size (MB)", fontsize=13)
    axes[3].grid(True)

    plt.tight_layout()
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()

    print(f"Plot saved to {filename}")

# %%
def summarize_metrics(metrics, filename):
    rounds = np.array(metrics["round"])
    losses = np.array(metrics["loss"])
    accs = np.array(metrics["accuracy"])
    round_times = np.array(metrics["round_time"])
    model_sizes = np.array(metrics["model_size"])

    mean_round_time = np.nanmean(round_times)
    std_round_time = np.nanstd(round_times)
    total_training_time = np.nansum(round_times)

    initial_model_size = model_sizes[0]
    final_model_size = model_sizes[-1]
    size_reduction = initial_model_size - final_model_size
    size_reduction_pct = (size_reduction / initial_model_size) * 100 if initial_model_size > 0 else 0

    final_loss = losses[-1]
    final_acc = accs[-1]
    best_acc = np.nanmax(accs)
    best_round = rounds[np.nanargmax(accs)]

    acc_per_mb = final_acc / final_model_size if final_model_size > 0 else np.nan

    summary = {
        "final_loss": float(final_loss),
        "final_accuracy": float(final_acc),
        "best_accuracy": float(best_acc),
        "best_round": int(best_round),
        "mean_round_time": float(mean_round_time),
        "std_round_time": float(std_round_time),
        "total_training_time": float(total_training_time),
        "initial_model_size_MB": float(initial_model_size),
        "final_model_size_MB": float(final_model_size),
        "size_reduction_MB": float(size_reduction),
        "size_reduction_pct": float(size_reduction_pct),
        "accuracy_per_MB": float(acc_per_mb)
    }

    print("=== Training Summary ===")
    print(f"Final loss: {summary['final_loss']:.4f}")
    print(f"Final accuracy: {summary['final_accuracy']:.4f}")
    print(f"Best accuracy: {summary['best_accuracy']:.4f}")
    print(f"Best round: {summary['best_round']}")
    print(f"Mean round time: {summary['mean_round_time']:.3f} s")
    print(f"Std round time: {summary['std_round_time']:.3f} s")
    print(f"Total training time: {summary['total_training_time']:.3f} s")
    print(f"Initial model size: {summary['initial_model_size_MB']:.3f} MB")
    print(f"Final model size: {summary['final_model_size_MB']:.3f} MB")
    print(f"Size reduction: {summary['size_reduction_MB']:.3f} MB ({summary['size_reduction_pct']:.2f}%)")
    print(f"Accuracy per MB: {summary['accuracy_per_MB']:.4f}")

    with open(filename, "w") as f:
        json.dump(summary, f, indent=4)

    print(f"\nSummary saved to {filename}")
    return summary

# %%
# Run loop
run_save_dir = "checkpoints"
metrics = federated_learning_loop_int8(run_save_dir)
# Out:
# Round 1
# Time evaluation
# loss: 2.3435, acc: 0.0991
# Durée de evaluate : 3.585 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.0991)
#
# Round 2
# Time evaluation
# loss: 2.4091, acc: 0.0999
# Durée de evaluate : 3.499 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.0999)
#
# Round 3
# Time evaluation
# loss: 2.4233, acc: 0.1006
# Durée de evaluate : 3.515 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.1006)
#
# Round 4
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.4233, acc: 0.1006
# Durée de evaluate : 4.102 s
# Total sent this round (INT4): 0.000 MB
#
# Round 5
# Time evaluation
# loss: 2.3944, acc: 0.1113
# Durée de evaluate : 3.523 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.1113)
#
# Round 6
# Time evaluation
# loss: 2.3845, acc: 0.1058
# Durée de evaluate : 3.578 s
# Total sent this round (INT4): 22.802 MB
#
# Round 7
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.3845, acc: 0.1058
# Durée de evaluate : 4.162 s
# Total sent this round (INT4): 0.000 MB
#
# Round 8
# Time evaluation
# loss: 2.6020, acc: 0.0972
# Durée de evaluate : 3.493 s
# Total sent this round (INT4): 5.700 MB
#
# Round 9
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.6020, acc: 0.0972
# Durée de evaluate : 3.980 s
# Total sent this round (INT4): 0.000 MB
#
# Round 10
# Time evaluation
# loss: 2.3772, acc: 0.1156
# Durée de evaluate : 4.612 s
# Total sent this round (INT4): 5.700 MB
# New best model saved (acc=0.1156)
#
# Round 11
# Time evaluation
# loss: 2.4406, acc: 0.1000
# Durée de evaluate : 3.523 s
# Total sent this round (INT4): 11.401 MB
#
# Round 12
# Time evaluation
# loss: 2.3865, acc: 0.1240
# Durée de evaluate : 3.513 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.1240)
#
# Round 13
# Time evaluation
# loss: 2.5815, acc: 0.1010
# Durée de evaluate : 3.604 s
# Total sent this round (INT4): 5.700 MB
#
# Round 14
# Time evaluation
# loss: 2.6025, acc: 0.0893
# Durée de evaluate : 3.454 s
# Total sent this round (INT4): 5.700 MB
#
# Round 15
# Time evaluation
# loss: 2.3254, acc: 0.1091
# Durée de evaluate : 3.603 s
# Total sent this round (INT4): 22.802 MB
#
# Round 16
# Time evaluation
# loss: 2.3589, acc: 0.0990
# Durée de evaluate : 3.571 s
# Total sent this round (INT4): 11.401 MB
#
# Round 17
# Time evaluation
# loss: 2.3401, acc: 0.1013
# Durée de evaluate : 4.072 s
# Total sent this round (INT4): 22.802 MB
#
# Round 18
# Time evaluation
# loss: 2.4242, acc: 0.1002
# Durée de evaluate : 4.075 s
# Total sent this round (INT4): 17.101 MB
#
# Round 19
# Time evaluation
# loss: 2.3064, acc: 0.1021
# Durée de evaluate : 3.561 s
# Total sent this round (INT4): 22.802 MB
#
# Round 20
# Time evaluation
# loss: 2.5588, acc: 0.1045
# Durée de evaluate : 4.095 s
# Total sent this round (INT4): 5.700 MB
#
# Round 21
# Time evaluation
# loss: 2.3033, acc: 0.1139
# Durée de evaluate : 3.636 s
# Total sent this round (INT4): 39.903 MB
#
# Round 22
# Time evaluation
# loss: 2.3293, acc: 0.1196
# Durée de evaluate : 3.472 s
# Total sent this round (INT4): 17.101 MB
#
# Round 23
# Time evaluation
# loss: 2.3305, acc: 0.1110
# Durée de evaluate : 3.551 s
# Total sent this round (INT4): 17.101 MB
#
# Round 24
# Time evaluation
# loss: 2.3255, acc: 0.1445
# Durée de evaluate : 3.507 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.1445)
#
# Round 25
# Time evaluation
# loss: 2.3520, acc: 0.1014
# Durée de evaluate : 3.773 s
# Total sent this round (INT4): 5.700 MB
#
# Round 26
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.3520, acc: 0.1014
# Durée de evaluate : 4.061 s
# Total sent this round (INT4): 0.000 MB
#
# Round 27
# Time evaluation
# loss: 2.3138, acc: 0.1157
# Durée de evaluate : 3.679 s
# Total sent this round (INT4): 5.700 MB
#
# Round 28
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.3138, acc: 0.1157
# Durée de evaluate : 4.150 s
# Total sent this round (INT4): 0.000 MB
#
# Round 29
# Time evaluation
# loss: 2.3844, acc: 0.0998
# Durée de evaluate : 3.612 s
# Total sent this round (INT4): 17.101 MB
#
# Round 30
# Time evaluation
# loss: 2.2910, acc: 0.1112
# Durée de evaluate : 3.687 s
# Total sent this round (INT4): 17.101 MB
#
# Round 31
# Time evaluation
# loss: 2.3894, acc: 0.1001
# Durée de evaluate : 3.606 s
# Total sent this round (INT4): 11.401 MB
#
# Round 32
# Time evaluation
# loss: 2.4973, acc: 0.0988
# Durée de evaluate : 3.930 s
# Total sent this round (INT4): 5.700 MB
#
# Round 33
# Time evaluation
# loss: 2.2518, acc: 0.1610
# Durée de evaluate : 4.188 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.1610)
#
# Round 34
# Time evaluation
# loss: 2.2813, acc: 0.1116
# Durée de evaluate : 4.036 s
# Total sent this round (INT4): 17.101 MB
#
# Round 35
# Time evaluation
# loss: 2.3016, acc: 0.1727
# Durée de evaluate : 4.110 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.1727)
#
# Round 36
# Time evaluation
# loss: 2.2837, acc: 0.1103
# Durée de evaluate : 3.648 s
# Total sent this round (INT4): 22.802 MB
#
# Round 37
# Time evaluation
# loss: 2.3142, acc: 0.1332
# Durée de evaluate : 3.553 s
# Total sent this round (INT4): 17.101 MB
#
# Round 38
# Time evaluation
# loss: 2.3349, acc: 0.1005
# Durée de evaluate : 4.077 s
# Total sent this round (INT4): 22.802 MB
#
# Round 39
# Time evaluation
# loss: 2.3421, acc: 0.1010
# Durée de evaluate : 3.452 s
# Total sent this round (INT4): 5.700 MB
#
# Round 40
# Time evaluation
# loss: 2.2964, acc: 0.1364
# Durée de evaluate : 3.546 s
# Total sent this round (INT4): 17.101 MB
#
# Round 41
# Time evaluation
# loss: 2.2523, acc: 0.1597
# Durée de evaluate : 4.017 s
# Total sent this round (INT4): 5.700 MB
#
# Round 42
# Time evaluation
# loss: 2.2305, acc: 0.1609
# Durée de evaluate : 3.614 s
# Total sent this round (INT4): 17.101 MB
#
# Round 43
# Time evaluation
# loss: 2.4077, acc: 0.1469
# Durée de evaluate : 3.703 s
# Total sent this round (INT4): 5.700 MB
#
# Round 44
# Time evaluation
# loss: 2.3009, acc: 0.1059
# Durée de evaluate : 3.605 s
# Total sent this round (INT4): 11.401 MB
#
# Round 45
# Time evaluation
# loss: 11.8920, acc: 0.1003
# Durée de evaluate : 3.505 s
# Total sent this round (INT4): 5.700 MB
#
# Round 46
# Time evaluation
# loss: 2.3327, acc: 0.1453
# Durée de evaluate : 3.552 s
# Total sent this round (INT4): 22.802 MB
#
# Round 47
# Time evaluation
# loss: 4.9858, acc: 0.1554
# Durée de evaluate : 3.476 s
# Total sent this round (INT4): 5.700 MB
#
# Round 48
# Time evaluation
# loss: 3.0659, acc: 0.2000
# Durée de evaluate : 3.703 s
# Total sent this round (INT4): 5.700 MB
# New best model saved (acc=0.2000)
#
# Round 49
# Time evaluation
# loss: 3.2410, acc: 0.1853
# Durée de evaluate : 3.514 s
# Total sent this round (INT4): 11.401 MB
#
# Round 50
# Time evaluation
# loss: 3.7189, acc: 0.2115
# Durée de evaluate : 3.518 s
# Total sent this round (INT4): 11.401 MB
# INT4 model update size: 5.700 MB
# New best model saved (acc=0.2115)
#
# Round 51
# Time evaluation
# loss: 3.0131, acc: 0.1494
# Durée de evaluate : 3.501 s
# Total sent this round (INT4): 17.101 MB
#
# Round 52
# Time evaluation
# loss: 2.2714, acc: 0.1847
# Durée de evaluate : 3.511 s
# Total sent this round (INT4): 17.101 MB
#
# Round 53
# Time evaluation
# loss: 3.1065, acc: 0.2040
# Durée de evaluate : 3.553 s
# Total sent this round (INT4): 5.700 MB
#
# Round 54
# Time evaluation
# loss: 2.4849, acc: 0.2369
# Durée de evaluate : 4.078 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.2369)
#
# Round 55
# Time evaluation
# loss: 3.0509, acc: 0.2151
# Durée de evaluate : 3.539 s
# Total sent this round (INT4): 5.700 MB
#
# Round 56
# Time evaluation
# loss: 2.5783, acc: 0.2154
# Durée de evaluate : 3.537 s
# Total sent this round (INT4): 5.700 MB
#
# Round 57
# Time evaluation
# loss: 5.0396, acc: 0.2344
# Durée de evaluate : 4.028 s
# Total sent this round (INT4): 11.401 MB
#
# Round 58
# Time evaluation
# loss: 2.5865, acc: 0.2714
# Durée de evaluate : 3.594 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.2714)
#
# Round 59
# Time evaluation
# loss: 3.3538, acc: 0.2409
# Durée de evaluate : 3.589 s
# Total sent this round (INT4): 17.101 MB
#
# Round 60
# Time evaluation
# loss: 4.3369, acc: 0.1971
# Durée de evaluate : 3.586 s
# Total sent this round (INT4): 11.401 MB
#
# Round 61
# Time evaluation
# loss: 2.9645, acc: 0.2546
# Durée de evaluate : 3.624 s
# Total sent this round (INT4): 17.101 MB
#
# Round 62
# Time evaluation
# loss: 2.1253, acc: 0.2853
# Durée de evaluate : 3.535 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.2853)
#
# Round 63
# Time evaluation
# loss: 2.0537, acc: 0.2557
# Durée de evaluate : 4.149 s
# Total sent this round (INT4): 5.700 MB
#
# Round 64
# Time evaluation
# loss: 2.4040, acc: 0.2442
# Durée de evaluate : 3.625 s
# Total sent this round (INT4): 5.700 MB
#
# Round 65
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.4040, acc: 0.2442
# Durée de evaluate : 4.219 s
# Total sent this round (INT4): 0.000 MB
#
# Round 66
# Time evaluation
# loss: 3.6758, acc: 0.2488
# Durée de evaluate : 3.597 s
# Total sent this round (INT4): 22.802 MB
#
# Round 67
# Time evaluation
# loss: 3.2767, acc: 0.2526
# Durée de evaluate : 3.669 s
# Total sent this round (INT4): 22.802 MB
#
# Round 68
# No client participated this round — keeping global model.
# Time evaluation
# loss: 3.2767, acc: 0.2526
# Durée de evaluate : 4.344 s
# Total sent this round (INT4): 0.000 MB
#
# Round 69
# Time evaluation
# loss: 2.7856, acc: 0.2378
# Durée de evaluate : 3.924 s
# Total sent this round (INT4): 17.101 MB
#
# Round 70
# Time evaluation
# loss: 2.5749, acc: 0.2790
# Durée de evaluate : 3.529 s
# Total sent this round (INT4): 5.700 MB
#
# Round 71
# Time evaluation
# loss: 3.0690, acc: 0.2481
# Durée de evaluate : 3.624 s
# Total sent this round (INT4): 11.401 MB
#
# Round 72
# No client participated this round — keeping global model.
# Time evaluation
# loss: 3.0690, acc: 0.2481
# Durée de evaluate : 4.361 s
# Total sent this round (INT4): 0.000 MB
#
# Round 73
# Time evaluation
# loss: 2.0695, acc: 0.3009
# Durée de evaluate : 3.607 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.3009)
#
# Round 74
# Time evaluation
# loss: 4.5305, acc: 0.2521
# Durée de evaluate : 3.742 s
# Total sent this round (INT4): 22.802 MB
#
# Round 75
# Time evaluation
# loss: 3.3202, acc: 0.2723
# Durée de evaluate : 4.128 s
# Total sent this round (INT4): 17.101 MB
#
# Round 76
# Time evaluation
# loss: 2.1757, acc: 0.2811
# Durée de evaluate : 3.593 s
# Total sent this round (INT4): 11.401 MB
#
# Round 77
# Time evaluation
# loss: 2.6685, acc: 0.2565
# Durée de evaluate : 3.627 s
# Total sent this round (INT4): 5.700 MB
#
# Round 78
# Time evaluation
# loss: 2.6350, acc: 0.2859
# Durée de evaluate : 3.605 s
# Total sent this round (INT4): 11.401 MB
#
# Round 79
# Time evaluation
# loss: 2.8499, acc: 0.3192
# Durée de evaluate : 4.116 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.3192)
#
# Round 80
# Time evaluation
# loss: 2.4756, acc: 0.3108
# Durée de evaluate : 4.068 s
# Total sent this round (INT4): 34.203 MB
#
# Round 81
# Time evaluation
# loss: 2.6504, acc: 0.3318
# Durée de evaluate : 3.561 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.3318)
#
# Round 82
# Time evaluation
# loss: 2.5262, acc: 0.3081
# Durée de evaluate : 3.571 s
# Total sent this round (INT4): 17.101 MB
#
# Round 83
# Time evaluation
# loss: 2.0780, acc: 0.2991
# Durée de evaluate : 4.090 s
# Total sent this round (INT4): 5.700 MB
#
# Round 84
# Time evaluation
# loss: 2.0808, acc: 0.3320
# Durée de evaluate : 3.565 s
# Total sent this round (INT4): 5.700 MB
# New best model saved (acc=0.3320)
#
# Round 85
# Time evaluation
# loss: 2.0777, acc: 0.3079
# Durée de evaluate : 3.590 s
# Total sent this round (INT4): 5.700 MB
#
# Round 86
# Time evaluation
# loss: 2.3507, acc: 0.3337
# Durée de evaluate : 3.535 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.3337)
#
# Round 87
# Time evaluation
# loss: 2.1272, acc: 0.3189
# Durée de evaluate : 4.228 s
# Total sent this round (INT4): 22.802 MB
#
# Round 88
# Time evaluation
# loss: 2.2148, acc: 0.3579
# Durée de evaluate : 3.493 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.3579)
#
# Round 89
# Time evaluation
# loss: 2.2665, acc: 0.3059
# Durée de evaluate : 4.159 s
# Total sent this round (INT4): 5.700 MB
#
# Round 90
# Time evaluation
# loss: 2.3909, acc: 0.3403
# Durée de evaluate : 3.893 s
# Total sent this round (INT4): 11.401 MB
#
# Round 91
# Time evaluation
# loss: 2.5121, acc: 0.3450
# Durée de evaluate : 3.547 s
# Total sent this round (INT4): 11.401 MB
#
# Round 92
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.5121, acc: 0.3450
# Durée de evaluate : 4.172 s
# Total sent this round (INT4): 0.000 MB
#
# Round 93
# Time evaluation
# loss: 2.3372, acc: 0.3500
# Durée de evaluate : 4.054 s
# Total sent this round (INT4): 11.401 MB
#
# Round 94
# Time evaluation
# loss: 1.8724, acc: 0.3545
# Durée de evaluate : 3.525 s
# Total sent this round (INT4): 5.700 MB
#
# Round 95
# Time evaluation
# loss: 1.8589, acc: 0.3377
# Durée de evaluate : 4.010 s
# Total sent this round (INT4): 5.700 MB
#
# Round 96
# Time evaluation
# loss: 1.9588, acc: 0.3602
# Durée de evaluate : 3.774 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.3602)
#
# Round 97
# Time evaluation
# loss: 1.9175, acc: 0.3591
# Durée de evaluate : 3.513 s
# Total sent this round (INT4): 22.802 MB
#
# Round 98
# Time evaluation
# loss: 1.8518, acc: 0.3418
# Durée de evaluate : 3.486 s
# Total sent this round (INT4): 11.401 MB
#
# Round 99
# Time evaluation
# loss: 1.9728, acc: 0.3521
# Durée de evaluate : 3.912 s
# Total sent this round (INT4): 11.401 MB
#
# Round 100
# Time evaluation
# loss: 1.8507, acc: 0.3631
# Durée de evaluate : 3.657 s
# Total sent this round (INT4): 17.101 MB
# INT4 model update size: 5.700 MB
# New best model saved (acc=0.3631)
#
# Round 101
# Time evaluation
# loss: 2.0657, acc: 0.3366
# Durée de evaluate : 4.140 s
# Total sent this round (INT4): 11.401 MB
#
# Round 102
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.0657, acc: 0.3366
# Durée de evaluate : 3.731 s
# Total sent this round (INT4): 0.000 MB
#
# Round 103
# Time evaluation
# loss: 2.0202, acc: 0.3677
# Durée de evaluate : 4.053 s
# Total sent this round (INT4): 28.502 MB
# New best model saved (acc=0.3677)
#
# Round 104
# Time evaluation
# loss: 2.2050, acc: 0.3472
# Durée de evaluate : 3.636 s
# Total sent this round (INT4): 11.401 MB
#
# Round 105
# Time evaluation
# loss: 1.8542, acc: 0.3539
# Durée de evaluate : 3.433 s
# Total sent this round (INT4): 5.700 MB
#
# Round 106
# Time evaluation
# loss: 1.9796, acc: 0.3575
# Durée de evaluate : 3.433 s
# Total sent this round (INT4): 11.401 MB
#
# Round 107
# Time evaluation
# loss: 2.0577, acc: 0.3587
# Durée de evaluate : 3.458 s
# Total sent this round (INT4): 5.700 MB
#
# Round 108
# Time evaluation
# loss: 2.2072, acc: 0.3540
# Durée de evaluate : 3.790 s
# Total sent this round (INT4): 17.101 MB
#
# Round 109
# Time evaluation
# loss: 2.1234, acc: 0.3625
# Durée de evaluate : 3.419 s
# Total sent this round (INT4): 5.700 MB
#
# Round 110
# Time evaluation
# loss: 1.9011, acc: 0.3730
# Durée de evaluate : 3.479 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.3730)
#
# Round 111
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.9011, acc: 0.3730
# Durée de evaluate : 3.920 s
# Total sent this round (INT4): 0.000 MB
#
# Round 112
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.9011, acc: 0.3730
# Durée de evaluate : 3.896 s
# Total sent this round (INT4): 0.000 MB
#
# Round 113
# Time evaluation
# loss: 1.7670, acc: 0.3750
# Durée de evaluate : 3.965 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.3750)
#
# Round 114
# Time evaluation
# loss: 2.3851, acc: 0.3522
# Durée de evaluate : 3.466 s
# Total sent this round (INT4): 5.700 MB
#
# Round 115
# Time evaluation
# loss: 2.8937, acc: 0.3533
# Durée de evaluate : 3.835 s
# Total sent this round (INT4): 5.700 MB
#
# Round 116
# Time evaluation
# loss: 1.8877, acc: 0.3629
# Durée de evaluate : 3.979 s
# Total sent this round (INT4): 11.401 MB
#
# Round 117
# Time evaluation
# loss: 1.8506, acc: 0.3551
# Durée de evaluate : 3.473 s
# Total sent this round (INT4): 11.401 MB
#
# Round 118
# Time evaluation
# loss: 2.1333, acc: 0.3757
# Durée de evaluate : 3.458 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.3757)
#
# Round 119
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.1333, acc: 0.3757
# Durée de evaluate : 4.179 s
# Total sent this round (INT4): 0.000 MB
#
# Round 120
# Time evaluation
# loss: 1.8100, acc: 0.3787
# Durée de evaluate : 3.523 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.3787)
#
# Round 121
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.8100, acc: 0.3787
# Durée de evaluate : 4.221 s
# Total sent this round (INT4): 0.000 MB
#
# Round 122
# Time evaluation
# loss: 1.8796, acc: 0.3688
# Durée de evaluate : 3.574 s
# Total sent this round (INT4): 17.101 MB
#
# Round 123
# Time evaluation
# loss: 2.0034, acc: 0.3504
# Durée de evaluate : 3.634 s
# Total sent this round (INT4): 5.700 MB
#
# Round 124
# No client participated this round — keeping global model.
# Time evaluation
# loss: 2.0034, acc: 0.3504
# Durée de evaluate : 4.047 s
# Total sent this round (INT4): 0.000 MB
#
# Round 125
# Time evaluation
# loss: 1.9526, acc: 0.3628
# Durée de evaluate : 4.062 s
# Total sent this round (INT4): 11.401 MB
#
# Round 126
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.9526, acc: 0.3628
# Durée de evaluate : 3.817 s
# Total sent this round (INT4): 0.000 MB
#
# Round 127
# Time evaluation
# loss: 2.0136, acc: 0.3539
# Durée de evaluate : 3.881 s
# Total sent this round (INT4): 5.700 MB
#
# Round 128
# Time evaluation
# loss: 1.8076, acc: 0.3787
# Durée de evaluate : 4.029 s
# Total sent this round (INT4): 17.101 MB
#
# Round 129
# Time evaluation
# loss: 1.8801, acc: 0.3576
# Durée de evaluate : 4.042 s
# Total sent this round (INT4): 17.101 MB
#
# Round 130
# Time evaluation
# loss: 2.2521, acc: 0.3768
# Durée de evaluate : 3.487 s
# Total sent this round (INT4): 22.802 MB
#
# Round 131
# Time evaluation
# loss: 1.8948, acc: 0.3662
# Durée de evaluate : 3.963 s
# Total sent this round (INT4): 5.700 MB
#
# Round 132
# Time evaluation
# loss: 1.7862, acc: 0.3716
# Durée de evaluate : 4.055 s
# Total sent this round (INT4): 17.101 MB
#
# Round 133
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7862, acc: 0.3716
# Durée de evaluate : 3.655 s
# Total sent this round (INT4): 0.000 MB
#
# Round 134
# Time evaluation
# loss: 2.0408, acc: 0.3773
# Durée de evaluate : 3.470 s
# Total sent this round (INT4): 11.401 MB
#
# Round 135
# Time evaluation
# loss: 1.8404, acc: 0.3692
# Durée de evaluate : 3.480 s
# Total sent this round (INT4): 17.101 MB
#
# Round 136
# Time evaluation
# loss: 1.7970, acc: 0.3619
# Durée de evaluate : 3.713 s
# Total sent this round (INT4): 11.401 MB
#
# Round 137
# Time evaluation
# loss: 2.0593, acc: 0.3623
# Durée de evaluate : 3.476 s
# Total sent this round (INT4): 17.101 MB
#
# Round 138
# Time evaluation
# loss: 1.9350, acc: 0.3778
# Durée de evaluate : 3.950 s
# Total sent this round (INT4): 11.401 MB
#
# Round 139
# Time evaluation
# loss: 2.2217, acc: 0.3527
# Durée de evaluate : 4.046 s
# Total sent this round (INT4): 11.401 MB
#
# Round 140
# Time evaluation
# loss: 1.8225, acc: 0.3773
# Durée de evaluate : 3.435 s
# Total sent this round (INT4): 11.401 MB
#
# Round 141
# Time evaluation
# loss: 2.3484, acc: 0.3600
# Durée de evaluate : 3.503 s
# Total sent this round (INT4): 5.700 MB
#
# Round 142
# Time evaluation
# loss: 1.8406, acc: 0.3877
# Durée de evaluate : 3.460 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.3877)
#
# Round 143
# Time evaluation
# loss: 1.9628, acc: 0.3807
# Durée de evaluate : 3.469 s
# Total sent this round (INT4): 34.203 MB
#
# Round 144
# Time evaluation
# loss: 1.7223, acc: 0.3965
# Durée de evaluate : 3.434 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.3965)
#
# Round 145
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7223, acc: 0.3965
# Durée de evaluate : 3.531 s
# Total sent this round (INT4): 0.000 MB
#
# Round 146
# Time evaluation
# loss: 1.9409, acc: 0.3773
# Durée de evaluate : 3.753 s
# Total sent this round (INT4): 17.101 MB
#
# Round 147
# Time evaluation
# loss: 1.7010, acc: 0.3832
# Durée de evaluate : 3.991 s
# Total sent this round (INT4): 17.101 MB
#
# Round 148
# Time evaluation
# loss: 1.7483, acc: 0.3617
# Durée de evaluate : 3.479 s
# Total sent this round (INT4): 11.401 MB
#
# Round 149
# Time evaluation
# loss: 1.7420, acc: 0.3715
# Durée de evaluate : 3.455 s
# Total sent this round (INT4): 11.401 MB
#
# Round 150
# Time evaluation
# loss: 1.7624, acc: 0.3829
# Durée de evaluate : 3.410 s
# Total sent this round (INT4): 11.401 MB
# INT4 model update size: 5.700 MB
#
# Round 151
# Time evaluation
# loss: 1.8248, acc: 0.3802
# Durée de evaluate : 3.514 s
# Total sent this round (INT4): 11.401 MB
#
# Round 152
# Time evaluation
# loss: 1.8008, acc: 0.3753
# Durée de evaluate : 3.486 s
# Total sent this round (INT4): 17.101 MB
#
# Round 153
# Time evaluation
# loss: 1.7999, acc: 0.3814
# Durée de evaluate : 3.973 s
# Total sent this round (INT4): 5.700 MB
#
# Round 154
# Time evaluation
# loss: 2.0021, acc: 0.3296
# Durée de evaluate : 3.482 s
# Total sent this round (INT4): 5.700 MB
#
# Round 155
# Time evaluation
# loss: 2.2669, acc: 0.3701
# Durée de evaluate : 3.752 s
# Total sent this round (INT4): 22.802 MB
#
# Round 156
# Time evaluation
# loss: 1.8066, acc: 0.3668
# Durée de evaluate : 3.921 s
# Total sent this round (INT4): 17.101 MB
#
# Round 157
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.8066, acc: 0.3668
# Durée de evaluate : 3.688 s
# Total sent this round (INT4): 0.000 MB
#
# Round 158
# Time evaluation
# loss: 1.7576, acc: 0.3686
# Durée de evaluate : 3.971 s
# Total sent this round (INT4): 11.401 MB
#
# Round 159
# Time evaluation
# loss: 1.9078, acc: 0.3815
# Durée de evaluate : 3.440 s
# Total sent this round (INT4): 5.700 MB
#
# Round 160
# Time evaluation
# loss: 1.9432, acc: 0.3753
# Durée de evaluate : 3.432 s
# Total sent this round (INT4): 11.401 MB
#
# Round 161
# Time evaluation
# loss: 1.7906, acc: 0.3845
# Durée de evaluate : 3.440 s
# Total sent this round (INT4): 11.401 MB
#
# Round 162
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7906, acc: 0.3845
# Durée de evaluate : 3.536 s
# Total sent this round (INT4): 0.000 MB
#
# Round 163
# Time evaluation
# loss: 1.7364, acc: 0.3811
# Durée de evaluate : 3.438 s
# Total sent this round (INT4): 17.101 MB
#
# Round 164
# Time evaluation
# loss: 1.8144, acc: 0.3714
# Durée de evaluate : 3.510 s
# Total sent this round (INT4): 11.401 MB
#
# Round 165
# Time evaluation
# loss: 1.7956, acc: 0.3449
# Durée de evaluate : 3.495 s
# Total sent this round (INT4): 11.401 MB
#
# Round 166
# Time evaluation
# loss: 1.9918, acc: 0.3738
# Durée de evaluate : 3.586 s
# Total sent this round (INT4): 22.802 MB
#
# Round 167
# Time evaluation
# loss: 2.1454, acc: 0.3626
# Durée de evaluate : 3.435 s
# Total sent this round (INT4): 11.401 MB
#
# Round 168
# Time evaluation
# loss: 1.9863, acc: 0.3743
# Durée de evaluate : 3.963 s
# Total sent this round (INT4): 22.802 MB
#
# Round 169
# Time evaluation
# loss: 1.7919, acc: 0.3761
# Durée de evaluate : 3.982 s
# Total sent this round (INT4): 17.101 MB
#
# Round 170
# Time evaluation
# loss: 1.6748, acc: 0.4097
# Durée de evaluate : 3.890 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.4097)
#
# Round 171
# Time evaluation
# loss: 1.7793, acc: 0.3592
# Durée de evaluate : 3.979 s
# Total sent this round (INT4): 17.101 MB
#
# Round 172
# Time evaluation
# loss: 2.1999, acc: 0.3426
# Durée de evaluate : 3.488 s
# Total sent this round (INT4): 5.700 MB
#
# Round 173
# Time evaluation
# loss: 1.9357, acc: 0.3776
# Durée de evaluate : 3.774 s
# Total sent this round (INT4): 5.700 MB
#
# Round 174
# Time evaluation
# loss: 2.1275, acc: 0.3863
# Durée de evaluate : 3.449 s
# Total sent this round (INT4): 5.700 MB
#
# Round 175
# Time evaluation
# loss: 1.8493, acc: 0.3814
# Durée de evaluate : 3.475 s
# Total sent this round (INT4): 17.101 MB
#
# Round 176
# Time evaluation
# loss: 1.7918, acc: 0.3869
# Durée de evaluate : 3.482 s
# Total sent this round (INT4): 11.401 MB
#
# Round 177
# Time evaluation
# loss: 1.9600, acc: 0.3655
# Durée de evaluate : 3.555 s
# Total sent this round (INT4): 17.101 MB
#
# Round 178
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.9600, acc: 0.3655
# Durée de evaluate : 4.119 s
# Total sent this round (INT4): 0.000 MB
#
# Round 179
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.9600, acc: 0.3655
# Durée de evaluate : 3.715 s
# Total sent this round (INT4): 0.000 MB
#
# Round 180
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.9600, acc: 0.3655
# Durée de evaluate : 3.657 s
# Total sent this round (INT4): 0.000 MB
#
# Round 181
# Time evaluation
# loss: 1.7495, acc: 0.3982
# Durée de evaluate : 3.467 s
# Total sent this round (INT4): 11.401 MB
#
# Round 182
# Time evaluation
# loss: 1.7551, acc: 0.3743
# Durée de evaluate : 3.480 s
# Total sent this round (INT4): 11.401 MB
#
# Round 183
# Time evaluation
# loss: 1.7214, acc: 0.3801
# Durée de evaluate : 4.020 s
# Total sent this round (INT4): 5.700 MB
#
# Round 184
# Time evaluation
# loss: 1.6906, acc: 0.3944
# Durée de evaluate : 4.123 s
# Total sent this round (INT4): 17.101 MB
#
# Round 185
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6906, acc: 0.3944
# Durée de evaluate : 3.712 s
# Total sent this round (INT4): 0.000 MB
#
# Round 186
# Time evaluation
# loss: 1.8553, acc: 0.3863
# Durée de evaluate : 3.508 s
# Total sent this round (INT4): 17.101 MB
#
# Round 187
# Time evaluation
# loss: 1.8103, acc: 0.3762
# Durée de evaluate : 4.038 s
# Total sent this round (INT4): 5.700 MB
#
# Round 188
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.8103, acc: 0.3762
# Durée de evaluate : 3.727 s
# Total sent this round (INT4): 0.000 MB
#
# Round 189
# Time evaluation
# loss: 1.7114, acc: 0.3806
# Durée de evaluate : 3.755 s
# Total sent this round (INT4): 11.401 MB
#
# Round 190
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7114, acc: 0.3806
# Durée de evaluate : 3.619 s
# Total sent this round (INT4): 0.000 MB
#
# Round 191
# Time evaluation
# loss: 1.7363, acc: 0.3815
# Durée de evaluate : 3.494 s
# Total sent this round (INT4): 11.401 MB
#
# Round 192
# Time evaluation
# loss: 1.7126, acc: 0.3890
# Durée de evaluate : 3.661 s
# Total sent this round (INT4): 11.401 MB
#
# Round 193
# Time evaluation
# loss: 1.8683, acc: 0.3637
# Durée de evaluate : 3.473 s
# Total sent this round (INT4): 5.700 MB
#
# Round 194
# Time evaluation
# loss: 1.9088, acc: 0.3890
# Durée de evaluate : 3.710 s
# Total sent this round (INT4): 17.101 MB
#
# Round 195
# Time evaluation
# loss: 1.7337, acc: 0.3938
# Durée de evaluate : 4.018 s
# Total sent this round (INT4): 17.101 MB
#
# Round 196
# Time evaluation
# loss: 1.6826, acc: 0.3973
# Durée de evaluate : 4.184 s
# Total sent this round (INT4): 17.101 MB
#
# Round 197
# Time evaluation
# loss: 1.7610, acc: 0.3769
# Durée de evaluate : 3.490 s
# Total sent this round (INT4): 5.700 MB
#
# Round 198
# Time evaluation
# loss: 1.6822, acc: 0.4017
# Durée de evaluate : 3.439 s
# Total sent this round (INT4): 17.101 MB
#
# Round 199
# Time evaluation
# loss: 1.7182, acc: 0.3818
# Durée de evaluate : 3.646 s
# Total sent this round (INT4): 17.101 MB
#
# Round 200
# Time evaluation
# loss: 1.7142, acc: 0.3913
# Durée de evaluate : 3.472 s
# Total sent this round (INT4): 28.502 MB
# INT4 model update size: 5.700 MB
#
# Round 201
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7142, acc: 0.3913
# Durée de evaluate : 3.548 s
# Total sent this round (INT4): 0.000 MB
#
# Round 202
# Time evaluation
# loss: 1.9588, acc: 0.3938
# Durée de evaluate : 3.472 s
# Total sent this round (INT4): 5.700 MB
#
# Round 203
# Time evaluation
# loss: 1.7353, acc: 0.3885
# Durée de evaluate : 3.510 s
# Total sent this round (INT4): 22.802 MB
#
# Round 204
# Time evaluation
# loss: 1.9371, acc: 0.3387
# Durée de evaluate : 3.479 s
# Total sent this round (INT4): 5.700 MB
#
# Round 205
# Time evaluation
# loss: 1.7194, acc: 0.3759
# Durée de evaluate : 3.688 s
# Total sent this round (INT4): 5.700 MB
#
# Round 206
# Time evaluation
# loss: 1.7029, acc: 0.3831
# Durée de evaluate : 3.462 s
# Total sent this round (INT4): 11.401 MB
#
# Round 207
# Time evaluation
# loss: 1.7324, acc: 0.3880
# Durée de evaluate : 4.046 s
# Total sent this round (INT4): 22.802 MB
#
# Round 208
# Time evaluation
# loss: 1.7651, acc: 0.3871
# Durée de evaluate : 3.534 s
# Total sent this round (INT4): 11.401 MB
#
# Round 209
# Time evaluation
# loss: 1.7071, acc: 0.3854
# Durée de evaluate : 3.798 s
# Total sent this round (INT4): 17.101 MB
#
# Round 210
# Time evaluation
# loss: 1.7787, acc: 0.3726
# Durée de evaluate : 3.414 s
# Total sent this round (INT4): 11.401 MB
#
# Round 211
# Time evaluation
# loss: 1.6546, acc: 0.4149
# Durée de evaluate : 3.842 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.4149)
#
# Round 212
# Time evaluation
# loss: 1.7593, acc: 0.3743
# Durée de evaluate : 3.473 s
# Total sent this round (INT4): 5.700 MB
#
# Round 213
# Time evaluation
# loss: 1.7863, acc: 0.3638
# Durée de evaluate : 3.486 s
# Total sent this round (INT4): 11.401 MB
#
# Round 214
# Time evaluation
# loss: 1.7407, acc: 0.3744
# Durée de evaluate : 3.489 s
# Total sent this round (INT4): 11.401 MB
#
# Round 215
# Time evaluation
# loss: 2.5701, acc: 0.3300
# Durée de evaluate : 3.957 s
# Total sent this round (INT4): 5.700 MB
#
# Round 216
# Time evaluation
# loss: 1.7333, acc: 0.3782
# Durée de evaluate : 3.430 s
# Total sent this round (INT4): 22.802 MB
#
# Round 217
# Time evaluation
# loss: 1.7257, acc: 0.3872
# Durée de evaluate : 3.409 s
# Total sent this round (INT4): 22.802 MB
#
# Round 218
# Time evaluation
# loss: 1.7540, acc: 0.3867
# Durée de evaluate : 3.456 s
# Total sent this round (INT4): 5.700 MB
#
# Round 219
# Time evaluation
# loss: 1.7841, acc: 0.3622
# Durée de evaluate : 3.574 s
# Total sent this round (INT4): 5.700 MB
#
# Round 220
# Time evaluation
# loss: 2.5558, acc: 0.3842
# Durée de evaluate : 3.418 s
# Total sent this round (INT4): 5.700 MB
#
# Round 221
# Time evaluation
# loss: 1.8707, acc: 0.3933
# Durée de evaluate : 3.652 s
# Total sent this round (INT4): 11.401 MB
#
# Round 222
# Time evaluation
# loss: 1.6680, acc: 0.3981
# Durée de evaluate : 3.968 s
# Total sent this round (INT4): 11.401 MB
#
# Round 223
# Time evaluation
# loss: 1.8742, acc: 0.3882
# Durée de evaluate : 3.537 s
# Total sent this round (INT4): 11.401 MB
#
# Round 224
# Time evaluation
# loss: 1.7707, acc: 0.4033
# Durée de evaluate : 3.470 s
# Total sent this round (INT4): 5.700 MB
#
# Round 225
# Time evaluation
# loss: 1.6401, acc: 0.4054
# Durée de evaluate : 3.460 s
# Total sent this round (INT4): 11.401 MB
#
# Round 226
# Time evaluation
# loss: 1.6717, acc: 0.4003
# Durée de evaluate : 3.489 s
# Total sent this round (INT4): 17.101 MB
#
# Round 227
# Time evaluation
# loss: 1.6696, acc: 0.4031
# Durée de evaluate : 3.484 s
# Total sent this round (INT4): 22.802 MB
#
# Round 228
# Time evaluation
# loss: 1.7290, acc: 0.3887
# Durée de evaluate : 3.420 s
# Total sent this round (INT4): 11.401 MB
#
# Round 229
# Time evaluation
# loss: 1.8816, acc: 0.3437
# Durée de evaluate : 3.798 s
# Total sent this round (INT4): 5.700 MB
#
# Round 230
# Time evaluation
# loss: 1.8935, acc: 0.3577
# Durée de evaluate : 3.440 s
# Total sent this round (INT4): 22.802 MB
#
# Round 231
# Time evaluation
# loss: 1.7553, acc: 0.3846
# Durée de evaluate : 3.460 s
# Total sent this round (INT4): 17.101 MB
#
# Round 232
# Time evaluation
# loss: 1.7412, acc: 0.3892
# Durée de evaluate : 3.498 s
# Total sent this round (INT4): 17.101 MB
#
# Round 233
# Time evaluation
# loss: 1.8715, acc: 0.3528
# Durée de evaluate : 3.434 s
# Total sent this round (INT4): 11.401 MB
#
# Round 234
# Time evaluation
# loss: 1.8551, acc: 0.4047
# Durée de evaluate : 3.978 s
# Total sent this round (INT4): 5.700 MB
#
# Round 235
# Time evaluation
# loss: 1.8511, acc: 0.3738
# Durée de evaluate : 3.745 s
# Total sent this round (INT4): 11.401 MB
#
# Round 236
# Time evaluation
# loss: 1.7595, acc: 0.3843
# Durée de evaluate : 3.945 s
# Total sent this round (INT4): 17.101 MB
#
# Round 237
# Time evaluation
# loss: 2.1043, acc: 0.3555
# Durée de evaluate : 3.449 s
# Total sent this round (INT4): 5.700 MB
#
# Round 238
# Time evaluation
# loss: 1.6927, acc: 0.3916
# Durée de evaluate : 3.509 s
# Total sent this round (INT4): 17.101 MB
#
# Round 239
# Time evaluation
# loss: 1.7941, acc: 0.4022
# Durée de evaluate : 3.718 s
# Total sent this round (INT4): 5.700 MB
#
# Round 240
# Time evaluation
# loss: 1.6944, acc: 0.4012
# Durée de evaluate : 3.424 s
# Total sent this round (INT4): 22.802 MB
#
# Round 241
# Time evaluation
# loss: 1.7035, acc: 0.3971
# Durée de evaluate : 3.514 s
# Total sent this round (INT4): 17.101 MB
#
# Round 242
# Time evaluation
# loss: 1.7502, acc: 0.3817
# Durée de evaluate : 3.432 s
# Total sent this round (INT4): 11.401 MB
#
# Round 243
# Time evaluation
# loss: 1.7024, acc: 0.3986
# Durée de evaluate : 3.451 s
# Total sent this round (INT4): 11.401 MB
#
# Round 244
# Time evaluation
# loss: 1.7935, acc: 0.3655
# Durée de evaluate : 3.810 s
# Total sent this round (INT4): 11.401 MB
#
# Round 245
# Time evaluation
# loss: 1.6641, acc: 0.4069
# Durée de evaluate : 3.942 s
# Total sent this round (INT4): 11.401 MB
#
# Round 246
# Time evaluation
# loss: 1.7099, acc: 0.3850
# Durée de evaluate : 3.408 s
# Total sent this round (INT4): 11.401 MB
#
# Round 247
# Time evaluation
# loss: 1.7510, acc: 0.3753
# Durée de evaluate : 3.447 s
# Total sent this round (INT4): 11.401 MB
#
# Round 248
# Time evaluation
# loss: 1.7495, acc: 0.3996
# Durée de evaluate : 3.455 s
# Total sent this round (INT4): 17.101 MB
#
# Round 249
# Time evaluation
# loss: 1.7493, acc: 0.3823
# Durée de evaluate : 3.463 s
# Total sent this round (INT4): 11.401 MB
#
# Round 250
# Time evaluation
# loss: 1.6833, acc: 0.3977
# Durée de evaluate : 3.443 s
# Total sent this round (INT4): 11.401 MB
# INT4 model update size: 5.700 MB
#
# Round 251
# Time evaluation
# loss: 1.7743, acc: 0.3967
# Durée de evaluate : 3.609 s
# Total sent this round (INT4): 5.700 MB
#
# Round 252
# Time evaluation
# loss: 1.8522, acc: 0.3752
# Durée de evaluate : 3.441 s
# Total sent this round (INT4): 11.401 MB
#
# Round 253
# Time evaluation
# loss: 1.8388, acc: 0.3735
# Durée de evaluate : 3.444 s
# Total sent this round (INT4): 5.700 MB
#
# Round 254
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.8388, acc: 0.3735
# Durée de evaluate : 3.515 s
# Total sent this round (INT4): 0.000 MB
#
# Round 255
# Time evaluation
# loss: 1.8118, acc: 0.3714
# Durée de evaluate : 3.433 s
# Total sent this round (INT4): 11.401 MB
#
# Round 256
# Time evaluation
# loss: 1.9816, acc: 0.4015
# Durée de evaluate : 3.689 s
# Total sent this round (INT4): 11.401 MB
#
# Round 257
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.9816, acc: 0.4015
# Durée de evaluate : 3.596 s
# Total sent this round (INT4): 0.000 MB
#
# Round 258
# Time evaluation
# loss: 1.7694, acc: 0.4099
# Durée de evaluate : 3.475 s
# Total sent this round (INT4): 11.401 MB
#
# Round 259
# Time evaluation
# loss: 1.8549, acc: 0.3674
# Durée de evaluate : 3.764 s
# Total sent this round (INT4): 5.700 MB
#
# Round 260
# Time evaluation
# loss: 1.7455, acc: 0.4061
# Durée de evaluate : 3.445 s
# Total sent this round (INT4): 11.401 MB
#
# Round 261
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7455, acc: 0.4061
# Durée de evaluate : 4.162 s
# Total sent this round (INT4): 0.000 MB
#
# Round 262
# Time evaluation
# loss: 1.6485, acc: 0.4144
# Durée de evaluate : 3.697 s
# Total sent this round (INT4): 17.101 MB
#
# Round 263
# Time evaluation
# loss: 1.7019, acc: 0.4045
# Durée de evaluate : 3.469 s
# Total sent this round (INT4): 22.802 MB
#
# Round 264
# Time evaluation
# loss: 1.7151, acc: 0.4098
# Durée de evaluate : 4.051 s
# Total sent this round (INT4): 5.700 MB
#
# Round 265
# Time evaluation
# loss: 1.7801, acc: 0.3953
# Durée de evaluate : 3.505 s
# Total sent this round (INT4): 22.802 MB
#
# Round 266
# Time evaluation
# loss: 1.7185, acc: 0.3802
# Durée de evaluate : 4.027 s
# Total sent this round (INT4): 5.700 MB
#
# Round 267
# Time evaluation
# loss: 1.6387, acc: 0.4164
# Durée de evaluate : 3.397 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.4164)
#
# Round 268
# Time evaluation
# loss: 1.6303, acc: 0.4167
# Durée de evaluate : 3.447 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.4167)
#
# Round 269
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6303, acc: 0.4167
# Durée de evaluate : 4.096 s
# Total sent this round (INT4): 0.000 MB
#
# Round 270
# Time evaluation
# loss: 1.7299, acc: 0.4091
# Durée de evaluate : 3.806 s
# Total sent this round (INT4): 17.101 MB
#
# Round 271
# Time evaluation
# loss: 1.6914, acc: 0.4125
# Durée de evaluate : 3.480 s
# Total sent this round (INT4): 17.101 MB
#
# Round 272
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6914, acc: 0.4125
# Durée de evaluate : 3.557 s
# Total sent this round (INT4): 0.000 MB
#
# Round 273
# Time evaluation
# loss: 1.7313, acc: 0.3943
# Durée de evaluate : 4.004 s
# Total sent this round (INT4): 5.700 MB
#
# Round 274
# Time evaluation
# loss: 1.7383, acc: 0.3916
# Durée de evaluate : 3.665 s
# Total sent this round (INT4): 17.101 MB
#
# Round 275
# Time evaluation
# loss: 1.6642, acc: 0.4050
# Durée de evaluate : 4.087 s
# Total sent this round (INT4): 11.401 MB
#
# Round 276
# Time evaluation
# loss: 1.7421, acc: 0.3856
# Durée de evaluate : 3.901 s
# Total sent this round (INT4): 17.101 MB
#
# Round 277
# Time evaluation
# loss: 2.3910, acc: 0.3664
# Durée de evaluate : 3.514 s
# Total sent this round (INT4): 5.700 MB
#
# Round 278
# Time evaluation
# loss: 1.6465, acc: 0.4059
# Durée de evaluate : 4.032 s
# Total sent this round (INT4): 22.802 MB
#
# Round 279
# Time evaluation
# loss: 1.6466, acc: 0.4274
# Durée de evaluate : 3.728 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.4274)
#
# Round 280
# Time evaluation
# loss: 1.6950, acc: 0.4003
# Durée de evaluate : 3.496 s
# Total sent this round (INT4): 17.101 MB
#
# Round 281
# Time evaluation
# loss: 1.6899, acc: 0.4026
# Durée de evaluate : 3.595 s
# Total sent this round (INT4): 22.802 MB
#
# Round 282
# Time evaluation
# loss: 1.8741, acc: 0.3918
# Durée de evaluate : 4.077 s
# Total sent this round (INT4): 22.802 MB
#
# Round 283
# Time evaluation
# loss: 1.9234, acc: 0.4160
# Durée de evaluate : 3.511 s
# Total sent this round (INT4): 5.700 MB
#
# Round 284
# Time evaluation
# loss: 2.1899, acc: 0.3822
# Durée de evaluate : 3.702 s
# Total sent this round (INT4): 5.700 MB
#
# Round 285
# Time evaluation
# loss: 1.7358, acc: 0.4014
# Durée de evaluate : 4.084 s
# Total sent this round (INT4): 11.401 MB
#
# Round 286
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7358, acc: 0.4014
# Durée de evaluate : 3.725 s
# Total sent this round (INT4): 0.000 MB
#
# Round 287
# Time evaluation
# loss: 1.7496, acc: 0.3851
# Durée de evaluate : 3.497 s
# Total sent this round (INT4): 22.802 MB
#
# Round 288
# Time evaluation
# loss: 1.7288, acc: 0.4090
# Durée de evaluate : 3.613 s
# Total sent this round (INT4): 17.101 MB
#
# Round 289
# Time evaluation
# loss: 1.6851, acc: 0.4176
# Durée de evaluate : 3.851 s
# Total sent this round (INT4): 17.101 MB
#
# Round 290
# Time evaluation
# loss: 1.7646, acc: 0.3985
# Durée de evaluate : 3.517 s
# Total sent this round (INT4): 5.700 MB
#
# Round 291
# Time evaluation
# loss: 1.6396, acc: 0.4118
# Durée de evaluate : 3.495 s
# Total sent this round (INT4): 11.401 MB
#
# Round 292
# Time evaluation
# loss: 1.9414, acc: 0.3643
# Durée de evaluate : 3.691 s
# Total sent this round (INT4): 5.700 MB
#
# Round 293
# Time evaluation
# loss: 1.6922, acc: 0.3993
# Durée de evaluate : 4.011 s
# Total sent this round (INT4): 17.101 MB
#
# Round 294
# Time evaluation
# loss: 2.1728, acc: 0.3955
# Durée de evaluate : 3.478 s
# Total sent this round (INT4): 11.401 MB
#
# Round 295
# Time evaluation
# loss: 1.6979, acc: 0.3903
# Durée de evaluate : 3.494 s
# Total sent this round (INT4): 11.401 MB
#
# Round 296
# Time evaluation
# loss: 1.7123, acc: 0.3928
# Durée de evaluate : 3.462 s
# Total sent this round (INT4): 17.101 MB
#
# Round 297
# Time evaluation
# loss: 1.7246, acc: 0.3759
# Durée de evaluate : 3.732 s
# Total sent this round (INT4): 17.101 MB
#
# Round 298
# Time evaluation
# loss: 1.8222, acc: 0.3790
# Durée de evaluate : 3.496 s
# Total sent this round (INT4): 11.401 MB
#
# Round 299
# Time evaluation
# loss: 1.7388, acc: 0.4030
# Durée de evaluate : 3.610 s
# Total sent this round (INT4): 11.401 MB
#
# Round 300
# Time evaluation
# loss: 1.7438, acc: 0.3864
# Durée de evaluate : 3.440 s
# Total sent this round (INT4): 11.401 MB
# INT4 model update size: 5.700 MB
#
# Round 301
# Time evaluation
# loss: 1.7809, acc: 0.3890
# Durée de evaluate : 3.758 s
# Total sent this round (INT4): 5.700 MB
#
# Round 302
# Time evaluation
# loss: 1.7207, acc: 0.4031
# Durée de evaluate : 4.060 s
# Total sent this round (INT4): 17.101 MB
#
# Round 303
# Time evaluation
# loss: 1.7244, acc: 0.3878
# Durée de evaluate : 4.101 s
# Total sent this round (INT4): 17.101 MB
#
# Round 304
# Time evaluation
# loss: 1.6811, acc: 0.4120
# Durée de evaluate : 3.948 s
# Total sent this round (INT4): 11.401 MB
#
# Round 305
# Time evaluation
# loss: 1.9838, acc: 0.3858
# Durée de evaluate : 4.004 s
# Total sent this round (INT4): 17.101 MB
#
# Round 306
# Time evaluation
# loss: 1.6868, acc: 0.4017
# Durée de evaluate : 3.869 s
# Total sent this round (INT4): 17.101 MB
#
# Round 307
# Time evaluation
# loss: 1.6955, acc: 0.4047
# Durée de evaluate : 4.005 s
# Total sent this round (INT4): 11.401 MB
#
# Round 308
# Time evaluation
# loss: 1.7660, acc: 0.3736
# Durée de evaluate : 3.480 s
# Total sent this round (INT4): 5.700 MB
#
# Round 309
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7660, acc: 0.3736
# Durée de evaluate : 3.738 s
# Total sent this round (INT4): 0.000 MB
#
# Round 310
# Time evaluation
# loss: 1.8007, acc: 0.3716
# Durée de evaluate : 3.457 s
# Total sent this round (INT4): 5.700 MB
#
# Round 311
# Time evaluation
# loss: 1.6539, acc: 0.4286
# Durée de evaluate : 3.494 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.4286)
#
# Round 312
# Time evaluation
# loss: 1.6093, acc: 0.4286
# Durée de evaluate : 3.665 s
# Total sent this round (INT4): 28.502 MB
#
# Round 313
# Time evaluation
# loss: 1.7015, acc: 0.4227
# Durée de evaluate : 4.104 s
# Total sent this round (INT4): 5.700 MB
#
# Round 314
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7015, acc: 0.4227
# Durée de evaluate : 4.073 s
# Total sent this round (INT4): 0.000 MB
#
# Round 315
# Time evaluation
# loss: 1.8096, acc: 0.4361
# Durée de evaluate : 3.496 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.4361)
#
# Round 316
# Time evaluation
# loss: 1.6646, acc: 0.4244
# Durée de evaluate : 3.652 s
# Total sent this round (INT4): 11.401 MB
#
# Round 317
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6646, acc: 0.4244
# Durée de evaluate : 3.645 s
# Total sent this round (INT4): 0.000 MB
#
# Round 318
# Time evaluation
# loss: 1.6497, acc: 0.4332
# Durée de evaluate : 3.762 s
# Total sent this round (INT4): 22.802 MB
#
# Round 319
# Time evaluation
# loss: 1.6693, acc: 0.4212
# Durée de evaluate : 4.087 s
# Total sent this round (INT4): 17.101 MB
#
# Round 320
# Time evaluation
# loss: 1.6948, acc: 0.4215
# Durée de evaluate : 3.474 s
# Total sent this round (INT4): 11.401 MB
#
# Round 321
# Time evaluation
# loss: 1.7109, acc: 0.4146
# Durée de evaluate : 3.467 s
# Total sent this round (INT4): 5.700 MB
#
# Round 322
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7109, acc: 0.4146
# Durée de evaluate : 3.590 s
# Total sent this round (INT4): 0.000 MB
#
# Round 323
# Time evaluation
# loss: 2.0605, acc: 0.4057
# Durée de evaluate : 3.447 s
# Total sent this round (INT4): 5.700 MB
#
# Round 324
# Time evaluation
# loss: 1.7299, acc: 0.4061
# Durée de evaluate : 3.921 s
# Total sent this round (INT4): 11.401 MB
#
# Round 325
# Time evaluation
# loss: 1.6502, acc: 0.4298
# Durée de evaluate : 3.938 s
# Total sent this round (INT4): 11.401 MB
#
# Round 326
# Time evaluation
# loss: 1.7148, acc: 0.3895
# Durée de evaluate : 3.470 s
# Total sent this round (INT4): 5.700 MB
#
# Round 327
# Time evaluation
# loss: 2.0736, acc: 0.3904
# Durée de evaluate : 4.135 s
# Total sent this round (INT4): 5.700 MB
#
# Round 328
# Time evaluation
# loss: 1.6745, acc: 0.4259
# Durée de evaluate : 3.464 s
# Total sent this round (INT4): 22.802 MB
#
# Round 329
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6745, acc: 0.4259
# Durée de evaluate : 3.589 s
# Total sent this round (INT4): 0.000 MB
#
# Round 330
# Time evaluation
# loss: 1.7137, acc: 0.4388
# Durée de evaluate : 4.013 s
# Total sent this round (INT4): 22.802 MB
# New best model saved (acc=0.4388)
#
# Round 331
# Time evaluation
# loss: 1.7490, acc: 0.4279
# Durée de evaluate : 3.742 s
# Total sent this round (INT4): 17.101 MB
#
# Round 332
# Time evaluation
# loss: 2.7247, acc: 0.3925
# Durée de evaluate : 3.462 s
# Total sent this round (INT4): 5.700 MB
#
# Round 333
# Time evaluation
# loss: 1.6230, acc: 0.4465
# Durée de evaluate : 3.571 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.4465)
#
# Round 334
# Time evaluation
# loss: 2.1694, acc: 0.3672
# Durée de evaluate : 3.808 s
# Total sent this round (INT4): 5.700 MB
#
# Round 335
# Time evaluation
# loss: 1.7648, acc: 0.4235
# Durée de evaluate : 3.494 s
# Total sent this round (INT4): 17.101 MB
#
# Round 336
# Time evaluation
# loss: 1.6474, acc: 0.4352
# Durée de evaluate : 3.485 s
# Total sent this round (INT4): 22.802 MB
#
# Round 337
# Time evaluation
# loss: 1.7389, acc: 0.4268
# Durée de evaluate : 3.484 s
# Total sent this round (INT4): 11.401 MB
#
# Round 338
# Time evaluation
# loss: 1.6492, acc: 0.4342
# Durée de evaluate : 3.601 s
# Total sent this round (INT4): 22.802 MB
#
# Round 339
# Time evaluation
# loss: 1.6765, acc: 0.4273
# Durée de evaluate : 3.838 s
# Total sent this round (INT4): 17.101 MB
#
# Round 340
# Time evaluation
# loss: 1.6371, acc: 0.4322
# Durée de evaluate : 3.483 s
# Total sent this round (INT4): 11.401 MB
#
# Round 341
# Time evaluation
# loss: 1.6135, acc: 0.4352
# Durée de evaluate : 3.767 s
# Total sent this round (INT4): 17.101 MB
#
# Round 342
# Time evaluation
# loss: 1.7470, acc: 0.4056
# Durée de evaluate : 3.481 s
# Total sent this round (INT4): 11.401 MB
#
# Round 343
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7470, acc: 0.4056
# Durée de evaluate : 4.192 s
# Total sent this round (INT4): 0.000 MB
#
# Round 344
# Time evaluation
# loss: 1.7112, acc: 0.4346
# Durée de evaluate : 3.479 s
# Total sent this round (INT4): 5.700 MB
#
# Round 345
# Time evaluation
# loss: 1.7758, acc: 0.4287
# Durée de evaluate : 3.571 s
# Total sent this round (INT4): 11.401 MB
#
# Round 346
# Time evaluation
# loss: 1.6773, acc: 0.4346
# Durée de evaluate : 3.563 s
# Total sent this round (INT4): 17.101 MB
#
# Round 347
# Time evaluation
# loss: 1.6431, acc: 0.4440
# Durée de evaluate : 3.541 s
# Total sent this round (INT4): 17.101 MB
#
# Round 348
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6431, acc: 0.4440
# Durée de evaluate : 4.077 s
# Total sent this round (INT4): 0.000 MB
#
# Round 349
# Time evaluation
# loss: 1.7276, acc: 0.4303
# Durée de evaluate : 4.062 s
# Total sent this round (INT4): 17.101 MB
#
# Round 350
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7276, acc: 0.4303
# Durée de evaluate : 3.646 s
# Total sent this round (INT4): 0.000 MB
# INT4 model update size: 5.700 MB
#
# Round 351
# Time evaluation
# loss: 1.7497, acc: 0.4183
# Durée de evaluate : 3.679 s
# Total sent this round (INT4): 11.401 MB
#
# Round 352
# Time evaluation
# loss: 1.7791, acc: 0.4136
# Durée de evaluate : 3.437 s
# Total sent this round (INT4): 5.700 MB
#
# Round 353
# Time evaluation
# loss: 1.6304, acc: 0.4375
# Durée de evaluate : 3.590 s
# Total sent this round (INT4): 11.401 MB
#
# Round 354
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6304, acc: 0.4375
# Durée de evaluate : 3.885 s
# Total sent this round (INT4): 0.000 MB
#
# Round 355
# Time evaluation
# loss: 1.6280, acc: 0.4415
# Durée de evaluate : 3.746 s
# Total sent this round (INT4): 22.802 MB
#
# Round 356
# Time evaluation
# loss: 1.6381, acc: 0.4412
# Durée de evaluate : 3.461 s
# Total sent this round (INT4): 22.802 MB
#
# Round 357
# Time evaluation
# loss: 1.6620, acc: 0.4350
# Durée de evaluate : 4.047 s
# Total sent this round (INT4): 5.700 MB
#
# Round 358
# Time evaluation
# loss: 1.6554, acc: 0.4314
# Durée de evaluate : 3.459 s
# Total sent this round (INT4): 5.700 MB
#
# Round 359
# Time evaluation
# loss: 1.8704, acc: 0.4038
# Durée de evaluate : 3.585 s
# Total sent this round (INT4): 11.401 MB
#
# Round 360
# Time evaluation
# loss: 1.6419, acc: 0.4448
# Durée de evaluate : 3.593 s
# Total sent this round (INT4): 22.802 MB
#
# Round 361
# Time evaluation
# loss: 1.7786, acc: 0.4065
# Durée de evaluate : 3.496 s
# Total sent this round (INT4): 5.700 MB
#
# Round 362
# Time evaluation
# loss: 1.6745, acc: 0.4387
# Durée de evaluate : 4.001 s
# Total sent this round (INT4): 5.700 MB
#
# Round 363
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6745, acc: 0.4387
# Durée de evaluate : 3.677 s
# Total sent this round (INT4): 0.000 MB
#
# Round 364
# Time evaluation
# loss: 1.6413, acc: 0.4444
# Durée de evaluate : 3.440 s
# Total sent this round (INT4): 17.101 MB
#
# Round 365
# Time evaluation
# loss: 1.6930, acc: 0.4369
# Durée de evaluate : 3.617 s
# Total sent this round (INT4): 11.401 MB
#
# Round 366
# Time evaluation
# loss: 1.7101, acc: 0.4345
# ...
# Time evaluation
# loss: 1.6975, acc: 0.4578
# Durée de evaluate : 3.603 s
# Total sent this round (INT4): 0.000 MB
#
# Round 627
# Time evaluation
# loss: 1.6962, acc: 0.4572
# Durée de evaluate : 3.538 s
# Total sent this round (INT4): 17.101 MB
#
# Round 628
# Time evaluation
# loss: 1.7444, acc: 0.4525
# Durée de evaluate : 3.940 s
# Total sent this round (INT4): 17.101 MB
#
# Round 629
# Time evaluation
# loss: 1.9685, acc: 0.4375
# Durée de evaluate : 3.537 s
# Total sent this round (INT4): 11.401 MB
#
# Round 630
# Time evaluation
# loss: 1.7296, acc: 0.4199
# Durée de evaluate : 3.583 s
# Total sent this round (INT4): 5.700 MB
#
# Round 631
# Time evaluation
# loss: 1.8262, acc: 0.4374
# Durée de evaluate : 3.551 s
# Total sent this round (INT4): 17.101 MB
#
# Round 632
# Time evaluation
# loss: 1.7381, acc: 0.4317
# Durée de evaluate : 3.459 s
# Total sent this round (INT4): 11.401 MB
#
# Round 633
# Time evaluation
# loss: 1.7127, acc: 0.4504
# Durée de evaluate : 4.024 s
# Total sent this round (INT4): 11.401 MB
#
# Round 634
# Time evaluation
# loss: 1.7122, acc: 0.4389
# Durée de evaluate : 3.462 s
# Total sent this round (INT4): 5.700 MB
#
# Round 635
# Time evaluation
# loss: 1.7930, acc: 0.4423
# Durée de evaluate : 4.062 s
# Total sent this round (INT4): 22.802 MB
#
# Round 636
# Time evaluation
# loss: 1.9846, acc: 0.4273
# Durée de evaluate : 3.454 s
# Total sent this round (INT4): 5.700 MB
#
# Round 637
# Time evaluation
# loss: 1.7006, acc: 0.4535
# Durée de evaluate : 3.440 s
# Total sent this round (INT4): 17.101 MB
#
# Round 638
# Time evaluation
# loss: 1.8810, acc: 0.4434
# Durée de evaluate : 3.452 s
# Total sent this round (INT4): 5.700 MB
#
# Round 639
# Time evaluation
# loss: 2.0043, acc: 0.4209
# Durée de evaluate : 3.755 s
# Total sent this round (INT4): 5.700 MB
#
# Round 640
# Time evaluation
# loss: 1.8182, acc: 0.4456
# Durée de evaluate : 3.925 s
# Total sent this round (INT4): 17.101 MB
#
# Round 641
# Time evaluation
# loss: 1.8224, acc: 0.4407
# Durée de evaluate : 4.023 s
# Total sent this round (INT4): 17.101 MB
#
# Round 642
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.8224, acc: 0.4407
# Durée de evaluate : 3.640 s
# Total sent this round (INT4): 0.000 MB
#
# Round 643
# Time evaluation
# loss: 1.6858, acc: 0.4326
# Durée de evaluate : 4.033 s
# Total sent this round (INT4): 5.700 MB
#
# Round 644
# Time evaluation
# loss: 1.7416, acc: 0.4553
# Durée de evaluate : 3.619 s
# Total sent this round (INT4): 11.401 MB
#
# Round 645
# Time evaluation
# loss: 1.7461, acc: 0.4409
# Durée de evaluate : 3.551 s
# Total sent this round (INT4): 11.401 MB
#
# Round 646
# Time evaluation
# loss: 1.6674, acc: 0.4511
# Durée de evaluate : 3.519 s
# Total sent this round (INT4): 11.401 MB
#
# Round 647
# Time evaluation
# loss: 1.7101, acc: 0.4642
# Durée de evaluate : 3.634 s
# Total sent this round (INT4): 22.802 MB
#
# Round 648
# Time evaluation
# loss: 1.6456, acc: 0.4498
# Durée de evaluate : 3.475 s
# Total sent this round (INT4): 5.700 MB
#
# Round 649
# Time evaluation
# loss: 1.8970, acc: 0.4119
# Durée de evaluate : 4.015 s
# Total sent this round (INT4): 5.700 MB
#
# Round 650
# Time evaluation
# loss: 1.7105, acc: 0.4427
# Durée de evaluate : 3.931 s
# Total sent this round (INT4): 17.101 MB
# INT4 model update size: 5.700 MB
#
# Round 651
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7105, acc: 0.4427
# Durée de evaluate : 3.582 s
# Total sent this round (INT4): 0.000 MB
#
# Round 652
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7105, acc: 0.4427
# Durée de evaluate : 3.671 s
# Total sent this round (INT4): 0.000 MB
#
# Round 653
# Time evaluation
# loss: 1.6618, acc: 0.4571
# Durée de evaluate : 3.399 s
# Total sent this round (INT4): 5.700 MB
#
# Round 654
# Time evaluation
# loss: 1.7203, acc: 0.4460
# Durée de evaluate : 3.805 s
# Total sent this round (INT4): 11.401 MB
#
# Round 655
# Time evaluation
# loss: 1.6153, acc: 0.4685
# Durée de evaluate : 3.915 s
# Total sent this round (INT4): 11.401 MB
# New best model saved (acc=0.4685)
#
# Round 656
# Time evaluation
# loss: 1.7125, acc: 0.4618
# Durée de evaluate : 3.975 s
# Total sent this round (INT4): 17.101 MB
#
# Round 657
# Time evaluation
# loss: 1.6953, acc: 0.4514
# Durée de evaluate : 3.676 s
# Total sent this round (INT4): 11.401 MB
#
# Round 658
# Time evaluation
# loss: 1.5692, acc: 0.4584
# Durée de evaluate : 3.436 s
# Total sent this round (INT4): 11.401 MB
#
# Round 659
# Time evaluation
# loss: 1.7066, acc: 0.4471
# Durée de evaluate : 4.044 s
# Total sent this round (INT4): 22.802 MB
#
# Round 660
# Time evaluation
# loss: 1.6938, acc: 0.4521
# Durée de evaluate : 3.394 s
# Total sent this round (INT4): 5.700 MB
#
# Round 661
# Time evaluation
# loss: 1.6835, acc: 0.4523
# Durée de evaluate : 3.971 s
# Total sent this round (INT4): 22.802 MB
#
# Round 662
# Time evaluation
# loss: 2.0160, acc: 0.4295
# Durée de evaluate : 3.406 s
# Total sent this round (INT4): 5.700 MB
#
# Round 663
# Time evaluation
# loss: 1.7081, acc: 0.4640
# Durée de evaluate : 3.387 s
# Total sent this round (INT4): 17.101 MB
#
# Round 664
# Time evaluation
# loss: 1.6911, acc: 0.4613
# Durée de evaluate : 3.518 s
# Total sent this round (INT4): 5.700 MB
#
# Round 665
# Time evaluation
# loss: 1.7025, acc: 0.4563
# Durée de evaluate : 3.423 s
# Total sent this round (INT4): 22.802 MB
#
# Round 666
# Time evaluation
# loss: 1.6736, acc: 0.4508
# Durée de evaluate : 3.420 s
# Total sent this round (INT4): 11.401 MB
#
# Round 667
# Time evaluation
# loss: 1.6916, acc: 0.4493
# Durée de evaluate : 3.404 s
# Total sent this round (INT4): 17.101 MB
#
# Round 668
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6916, acc: 0.4493
# Durée de evaluate : 3.521 s
# Total sent this round (INT4): 0.000 MB
#
# Round 669
# Time evaluation
# loss: 1.6816, acc: 0.4382
# Durée de evaluate : 3.487 s
# Total sent this round (INT4): 5.700 MB
#
# Round 670
# Time evaluation
# loss: 1.6798, acc: 0.4482
# Durée de evaluate : 3.638 s
# Total sent this round (INT4): 11.401 MB
#
# Round 671
# Time evaluation
# loss: 1.7218, acc: 0.4379
# Durée de evaluate : 3.406 s
# Total sent this round (INT4): 5.700 MB
#
# Round 672
# Time evaluation
# loss: 1.7068, acc: 0.4370
# Durée de evaluate : 3.447 s
# Total sent this round (INT4): 5.700 MB
#
# Round 673
# Time evaluation
# loss: 1.7267, acc: 0.4516
# Durée de evaluate : 3.605 s
# Total sent this round (INT4): 5.700 MB
#
# Round 674
# Time evaluation
# loss: 1.7088, acc: 0.4532
# Durée de evaluate : 3.429 s
# Total sent this round (INT4): 28.502 MB
#
# Round 675
# Time evaluation
# loss: 1.7761, acc: 0.4517
# Durée de evaluate : 3.448 s
# Total sent this round (INT4): 11.401 MB
#
# Round 676
# Time evaluation
# loss: 1.6684, acc: 0.4516
# Durée de evaluate : 3.976 s
# Total sent this round (INT4): 11.401 MB
#
# Round 677
# Time evaluation
# loss: 1.6313, acc: 0.4499
# Durée de evaluate : 3.402 s
# Total sent this round (INT4): 5.700 MB
#
# Round 678
# Time evaluation
# loss: 1.7628, acc: 0.4608
# Durée de evaluate : 3.437 s
# Total sent this round (INT4): 11.401 MB
#
# Round 679
# Time evaluation
# loss: 1.7079, acc: 0.4514
# Durée de evaluate : 3.422 s
# Total sent this round (INT4): 17.101 MB
#
# Round 680
# Time evaluation
# loss: 2.2431, acc: 0.4087
# Durée de evaluate : 4.000 s
# Total sent this round (INT4): 5.700 MB
#
# Round 681
# Time evaluation
# loss: 1.6526, acc: 0.4584
# Durée de evaluate : 3.752 s
# Total sent this round (INT4): 17.101 MB
#
# Round 682
# Time evaluation
# loss: 1.8007, acc: 0.4558
# Durée de evaluate : 3.926 s
# Total sent this round (INT4): 11.401 MB
#
# Round 683
# Time evaluation
# loss: 1.7720, acc: 0.4481
# Durée de evaluate : 3.392 s
# Total sent this round (INT4): 22.802 MB
#
# Round 684
# Time evaluation
# loss: 1.7224, acc: 0.4417
# Durée de evaluate : 3.932 s
# Total sent this round (INT4): 11.401 MB
#
# Round 685
# Time evaluation
# loss: 1.6280, acc: 0.4510
# Durée de evaluate : 3.770 s
# Total sent this round (INT4): 11.401 MB
#
# Round 686
# Time evaluation
# loss: 1.6491, acc: 0.4461
# Durée de evaluate : 3.433 s
# Total sent this round (INT4): 11.401 MB
#
# Round 687
# Time evaluation
# loss: 1.8413, acc: 0.4302
# Durée de evaluate : 3.400 s
# Total sent this round (INT4): 5.700 MB
#
# Round 688
# Time evaluation
# loss: 1.7711, acc: 0.4441
# Durée de evaluate : 3.446 s
# Total sent this round (INT4): 22.802 MB
#
# Round 689
# Time evaluation
# loss: 1.7281, acc: 0.4538
# Durée de evaluate : 3.411 s
# Total sent this round (INT4): 11.401 MB
#
# Round 690
# Time evaluation
# loss: 1.7107, acc: 0.4606
# Durée de evaluate : 3.423 s
# Total sent this round (INT4): 17.101 MB
#
# Round 691
# Time evaluation
# loss: 1.7313, acc: 0.4532
# Durée de evaluate : 3.948 s
# Total sent this round (INT4): 5.700 MB
#
# Round 692
# Time evaluation
# loss: 1.7929, acc: 0.4372
# Durée de evaluate : 3.488 s
# Total sent this round (INT4): 11.401 MB
#
# Round 693
# Time evaluation
# loss: 1.6691, acc: 0.4425
# Durée de evaluate : 3.645 s
# Total sent this round (INT4): 17.101 MB
#
# Round 694
# Time evaluation
# loss: 1.6647, acc: 0.4382
# Durée de evaluate : 3.426 s
# Total sent this round (INT4): 22.802 MB
#
# Round 695
# Time evaluation
# loss: 1.9087, acc: 0.4218
# Durée de evaluate : 3.446 s
# Total sent this round (INT4): 17.101 MB
#
# Round 696
# Time evaluation
# loss: 1.6933, acc: 0.4628
# Durée de evaluate : 3.874 s
# Total sent this round (INT4): 11.401 MB
#
# Round 697
# Time evaluation
# loss: 1.6855, acc: 0.4373
# Durée de evaluate : 3.898 s
# Total sent this round (INT4): 11.401 MB
#
# Round 698
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6855, acc: 0.4373
# Durée de evaluate : 3.535 s
# Total sent this round (INT4): 0.000 MB
#
# Round 699
# Time evaluation
# loss: 1.9602, acc: 0.4215
# Durée de evaluate : 3.515 s
# Total sent this round (INT4): 5.700 MB
#
# Round 700
# Time evaluation
# loss: 1.7263, acc: 0.4317
# Durée de evaluate : 3.409 s
# Total sent this round (INT4): 11.401 MB
# INT4 model update size: 5.700 MB
#
# Round 701
# Time evaluation
# loss: 1.7953, acc: 0.3989
# Durée de evaluate : 3.450 s
# Total sent this round (INT4): 5.700 MB
#
# Round 702
# Time evaluation
# loss: 1.5769, acc: 0.4547
# Durée de evaluate : 3.444 s
# Total sent this round (INT4): 17.101 MB
#
# Round 703
# Time evaluation
# loss: 1.5838, acc: 0.4708
# Durée de evaluate : 3.382 s
# Total sent this round (INT4): 17.101 MB
# New best model saved (acc=0.4708)
#
# Round 704
# Time evaluation
# loss: 1.6395, acc: 0.4436
# Durée de evaluate : 3.863 s
# Total sent this round (INT4): 5.700 MB
#
# Round 705
# Time evaluation
# loss: 1.5867, acc: 0.4516
# Durée de evaluate : 3.435 s
# Total sent this round (INT4): 11.401 MB
#
# Round 706
# Time evaluation
# loss: 1.7807, acc: 0.4238
# Durée de evaluate : 3.428 s
# Total sent this round (INT4): 5.700 MB
#
# Round 707
# Time evaluation
# loss: 1.6574, acc: 0.4401
# Durée de evaluate : 3.708 s
# Total sent this round (INT4): 11.401 MB
#
# Round 708
# Time evaluation
# loss: 1.6465, acc: 0.4576
# Durée de evaluate : 3.421 s
# Total sent this round (INT4): 17.101 MB
#
# Round 709
# Time evaluation
# loss: 1.6084, acc: 0.4533
# Durée de evaluate : 3.442 s
# Total sent this round (INT4): 17.101 MB
#
# Round 710
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6084, acc: 0.4533
# Durée de evaluate : 3.506 s
# Total sent this round (INT4): 0.000 MB
#
# Round 711
# Time evaluation
# loss: 1.5605, acc: 0.4559
# Durée de evaluate : 3.417 s
# Total sent this round (INT4): 11.401 MB
#
# Round 712
# Time evaluation
# loss: 1.7937, acc: 0.4191
# Durée de evaluate : 3.938 s
# Total sent this round (INT4): 5.700 MB
#
# Round 713
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.7937, acc: 0.4191
# Durée de evaluate : 3.556 s
# Total sent this round (INT4): 0.000 MB
#
# Round 714
# Time evaluation
# loss: 1.5426, acc: 0.4597
# Durée de evaluate : 3.789 s
# Total sent this round (INT4): 11.401 MB
#
# Round 715
# Time evaluation
# loss: 1.6289, acc: 0.4605
# Durée de evaluate : 3.464 s
# Total sent this round (INT4): 22.802 MB
#
# Round 716
# Time evaluation
# loss: 1.6584, acc: 0.4574
# Durée de evaluate : 3.600 s
# Total sent this round (INT4): 22.802 MB
#
# Round 717
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6584, acc: 0.4574
# Durée de evaluate : 3.934 s
# Total sent this round (INT4): 0.000 MB
#
# Round 718
# Time evaluation
# loss: 1.7313, acc: 0.4558
# Durée de evaluate : 3.420 s
# Total sent this round (INT4): 5.700 MB
#
# Round 719
# Time evaluation
# loss: 1.6660, acc: 0.4619
# Durée de evaluate : 3.418 s
# Total sent this round (INT4): 11.401 MB
#
# Round 720
# Time evaluation
# loss: 1.6604, acc: 0.4499
# Durée de evaluate : 3.908 s
# Total sent this round (INT4): 5.700 MB
#
# Round 721
# Time evaluation
# loss: 1.7324, acc: 0.4347
# Durée de evaluate : 3.439 s
# Total sent this round (INT4): 5.700 MB
#
# Round 722
# Time evaluation
# loss: 1.6252, acc: 0.4528
# Durée de evaluate : 3.985 s
# Total sent this round (INT4): 22.802 MB
#
# Round 723
# Time evaluation
# loss: 1.6343, acc: 0.4411
# Durée de evaluate : 3.443 s
# Total sent this round (INT4): 11.401 MB
#
# Round 724
# Time evaluation
# loss: 1.6462, acc: 0.4526
# Durée de evaluate : 3.411 s
# Total sent this round (INT4): 5.700 MB
#
# Round 725
# Time evaluation
# loss: 1.6560, acc: 0.4525
# Durée de evaluate : 3.733 s
# Total sent this round (INT4): 11.401 MB
#
# Round 726
# Time evaluation
# loss: 1.5480, acc: 0.4628
# Durée de evaluate : 3.975 s
# Total sent this round (INT4): 11.401 MB
#
# Round 727
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.5480, acc: 0.4628
# Durée de evaluate : 3.589 s
# Total sent this round (INT4): 0.000 MB
#
# Round 728
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.5480, acc: 0.4628
# Durée de evaluate : 3.709 s
# Total sent this round (INT4): 0.000 MB
#
# Round 729
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.5480, acc: 0.4628
# Durée de evaluate : 4.125 s
# Total sent this round (INT4): 0.000 MB
#
# Round 730
# Time evaluation
# loss: 1.5849, acc: 0.4555
# Durée de evaluate : 3.478 s
# Total sent this round (INT4): 11.401 MB
#
# Round 731
# Time evaluation
# loss: 1.5798, acc: 0.4488
# Durée de evaluate : 3.651 s
# Total sent this round (INT4): 17.101 MB
#
# Round 732
# Time evaluation
# loss: 1.7250, acc: 0.4435
# Durée de evaluate : 3.470 s
# Total sent this round (INT4): 5.700 MB
#
# Round 733
# Time evaluation
# loss: 1.6504, acc: 0.4457
# Durée de evaluate : 3.475 s
# Total sent this round (INT4): 11.401 MB
#
# Round 734
# Time evaluation
# loss: 1.6709, acc: 0.4400
# Durée de evaluate : 3.396 s
# Total sent this round (INT4): 17.101 MB
#
# Round 735
# Time evaluation
# loss: 1.6906, acc: 0.4304
# Durée de evaluate : 3.889 s
# Total sent this round (INT4): 5.700 MB
#
# Round 736
# Time evaluation
# loss: 1.5253, acc: 0.4619
# Durée de evaluate : 3.437 s
# Total sent this round (INT4): 11.401 MB
#
# Round 737
# Time evaluation
# loss: 1.5869, acc: 0.4611
# Durée de evaluate : 3.462 s
# Total sent this round (INT4): 11.401 MB
#
# Round 738
# Time evaluation
# loss: 1.6010, acc: 0.4437
# Durée de evaluate : 3.408 s
# Total sent this round (INT4): 11.401 MB
#
# Round 739
# Time evaluation
# loss: 1.5482, acc: 0.4618
# Durée de evaluate : 3.428 s
# Total sent this round (INT4): 17.101 MB
#
# Round 740
# Time evaluation
# loss: 1.6470, acc: 0.4473
# Durée de evaluate : 3.426 s
# Total sent this round (INT4): 17.101 MB
#
# Round 741
# No client participated this round — keeping global model.
# Time evaluation
# loss: 1.6470, acc: 0.4473
# Durée de evaluate : 3.856 s
# Total sent this round (INT4): 0.000 MB
#
# Round 742
# Time evaluation
# loss: 1.5679, acc: 0.4665
# Durée de evaluate : 3.995 s
# Total sent this round (INT4): 17.101 MB
#
# Round 743
# Time evaluation
# loss: 1.5898, acc: 0.4435
# Durée de evaluate : 3.421 s
# Total sent this round (INT4): 5.700 MB
#
# Round 744
# Time evaluation
# loss: 1.6248, acc: 0.4501
# Durée de evaluate : 3.409 s
# Total sent this round (INT4): 11.401 MB
#
# Round 745
# Time evaluation
# loss: 1.5523, acc: 0.4616
# Durée de evaluate : 3.444 s
# Total sent this round (INT4): 17.101 MB
#
# Round 746
# Time evaluation
# loss: 1.5474, acc: 0.4656
# Durée de evaluate : 3.394 s
# Total sent this round (INT4): 17.101 MB
#
# Round 747
# Time evaluation
# loss: 1.5319, acc: 0.4731
# Durée de evaluate : 4.092 s
# Total sent this round (INT4): 28.502 MB
# New best model saved (acc=0.4731)
#
# Round 748
# Time evaluation
# loss: 1.5958, acc: 0.4529
# Durée de evaluate : 3.523 s
# Total sent this round (INT4): 5.700 MB
#
# Round 749
# Time evaluation
# loss: 1.5583, acc: 0.4571
# Durée de evaluate : 3.423 s
# Total sent this round (INT4): 5.700 MB
#
# Round 750
# Time evaluation
# loss: 1.5472, acc: 0.4615
# Durée de evaluate : 3.415 s
# Total sent this round (INT4): 17.101 MB
# INT4 model update size: 5.700 MB
# Final model saved

# %%
# Compute summary statistics
summary_filename = "summary.json"
summary = summarize_metrics(metrics, summary_filename)
# Out:
# === Training Summary ===
# Final loss: 1.5472
# Final accuracy: 0.4615
# Best accuracy: 0.4731
# Best round: 747
# Mean round time: 6.281 s
# Std round time: 3.857 s
# Total training time: 4710.913 s
# Initial model size: 44.805 MB
# Final model size: 44.805 MB
# Size reduction: 0.000 MB (0.00%)
# Accuracy per MB: 0.0103
#
# Summary saved to summary.json

# %%
# Plot metrics
metrics_filename_int8 = "training_metrics_FP16.png"
plot_metrics(metrics, metrics_filename_int8)
# Out:
# Plot saved to training_metrics_FP16.png

# %%
# !zip -r /content/{run_save_dir}.zip /content/{run_save_dir}/
from google.colab import files
files.download(f"/content/{run_save_dir}.zip")
files.download(f"/content/{metrics_filename_int8}")
files.download(f"/content/{summary_filename}")
# Out:
#   adding: content/checkpoints/ (stored 0%)
#   adding: content/checkpoints/best_model.pth (deflated 7%)

# %%
def server_aggregate_models(clients):
    models = [x["local_model"].state_dict() for x in clients]
    averaged_model = copy.deepcopy(models[0])
    with torch.no_grad():
        for k in averaged_model.keys():
            averaged_model[k] = sum(m[k] for m in models) / len(models)
    return averaged_model


def quantification(clients) :
  models = clients["local_model"]
